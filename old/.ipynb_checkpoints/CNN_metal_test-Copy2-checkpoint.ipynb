# %%
import os
import sys
import subprocess
import glob as glob
import shlex
from scipy.signal import medfilt
from scipy.special import wofz
from scipy.signal import find_peaks
from scipy.ndimage import gaussian_filter1d
import matplotlib.pyplot as plt
import seaborn as sb
import healpy
import numpy as np
import desispec.io
import fitsio
from pathlib import Path

os.environ["CUDA_VISIBLE_DEVICES"] = ""

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
from astropy.io import fits
import glob

sb.set_style('white')

# 1) Paths
DESISIM_REPO = "/pscratch/sd/m/mherbold/desisim"
DESISIM_PY   = f"{DESISIM_REPO}/py"
DESIMODEL_REPO = "/pscratch/sd/m/mherbold/desidatamodel/py/desimodeldata"
DESIMODEL_PY   = f"{DESIMODEL_REPO}/py"

# 2) Make sure Python can import desisim from your clone
os.environ["PYTHONPATH"] = DESISIM_PY + (":" + os.environ["PYTHONPATH"] if "PYTHONPATH" in os.environ else "")
if DESISIM_PY not in sys.path:
    sys.path.insert(0, DESISIM_PY)
os.environ["PYTHONPATH"] = DESIMODEL_PY + (":" + os.environ["PYTHONPATH"] if "PYTHONPATH" in os.environ else "")
if DESIMODEL_PY not in sys.path:
    sys.path.insert(0, DESIMODEL_PY)
    
# Optional but often needed by DESI stack:
# os.environ["DESIMODEL"] = "/path/to/desimodel"
# os.environ["DESI_ROOT"] = "/path/to/desi_root"

# Set device to GPU if available, else CPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
device
# print(f"Using device: {device}")

print(torch.cuda.is_available())
# Out:
# False

# %%
# %matplotlib inline

# %%
# DR1 test
ifile = '/pscratch/sd/m/mherbold/tests/metal_CNN_test/QQ_output_test/transmission-16-1_2.fits'   # with z-mask

# full wavelength
outdir = '/pscratch/sd/m/mherbold/tests/metal_CNN_test/QQ_output_test/QQ_output_M-only-preproc/'

print(outdir) # Adjuts the path if this is not where you want to store the files produced by this tutorial
# Out:
# /pscratch/sd/m/mherbold/tests/metal_CNN_test/QQ_output_test/QQ_output_M-only-preproc/

# %% [markdown]
# ## CNN test

# %% [markdown]
# ### Metal-line CNN for Lyman-alpha forest mocks (quickquasars)
#
# This notebook (cell-marked `.py`, open with Jupytext or paste cells into Jupyter)
# builds a small 1D CNN that detects the rest-frame wavelength (i.e. which known
# metal transition) and strength (optical depth / EW-like amplitude) of metal
# contaminant lines injected by `quickquasars` into Lya-forest mock spectra.
#
# #### Design idea
# `quickquasars` generates metal absorption from the *same* density skewer as
# Lya, evaluated at the redshift implied by the metal's rest wavelength lambda_m
# instead of 1215.67 A. In log10(lambda_obs) space this is a **constant**
# additive shift:
#
#     delta_m = log10(1215.67 / lambda_m)
#
# independent of z_qso or z_absorber. That means the metal optical depth at a
# given pixel is (a scaled, noisy version of) the Lya forest optical depth at a
# *fixed* pixel offset elsewhere in the same spectrum. We exploit this by
# feeding the CNN the raw flux *and* copies of the flux shifted by each known
# delta_m as extra channels, turning "find a correlated echo far away in the
# spectrum" into a local regression problem.
#
# Adapt the TODO-marked I/O functions to your actual quickquasars output
# (spectra-*.fits / truth-*.fits / transmission-*.fits paths and HDU names).

# %% [markdown]
# #### 1. Config: grid, transitions, pixel shifts

# %%
LYA_REST = 1215.67  # Angstrom

# Match this EXACTLY to the --metals list you passed to quickquasars.
METAL_LINES_FULL = {
    "SiII_1190": 1190.4158,
    "SiII_1193": 1193.2897,
    "SiIII_1207": 1206.500,
    "SiII_1260": 1206.500,
    "CIV_1548": 1548.2049,
    "CIV_1550": 1550.77845,
    'MgI(2853)': 2852.96,
}


# current test case: single contaminant, exaggerated strength, for pipeline validation
METAL_LINES = {
    # "SiII_1304": 1304.37,
    'MgI(2853)': 2852.96,
}
 
# FOREST_MIN = 1040.0   # rest-frame forest window (quasar rest frame), Angstrom
# FOREST_MAX = 1200.0   # keep clear of the Lya emission line proximity zone
FOREST_MIN = 1040.0   
FOREST_MAX = 3500.0 

N_PIX = 256
 
LOG_MIN = np.log10(FOREST_MIN)
LOG_MAX = np.log10(FOREST_MAX)
DLOGLAM = (LOG_MAX - LOG_MIN) / N_PIX
REST_GRID = 10 ** (LOG_MIN + (np.arange(N_PIX) + 0.5) * DLOGLAM)
 
 
def pixel_shift(lambda_m):
    """Constant pixel offset (in the fixed log-lambda grid) between a metal
    echo and the Lya-forest pattern it was copied from."""
    delta_loglam = np.log10(LYA_REST / lambda_m)
    return int(round(delta_loglam / DLOGLAM))

def shift_edge_padded(arr, shift, pad_value=1.0):
    """Shift an array without wrap-around, padding exposed pixels.

    Parameters
    ----------
    arr : array-like
        Input spectrum.
    shift : int
        Number of pixels to shift. Positive shifts toward larger pixel index.
    pad_value : float
        Value used to fill pixels exposed by the shift. For normalized flux,
        1.0 corresponds to no absorption.

    Returns
    -------
    shifted : ndarray
        Shifted, edge-padded array with the same length as arr.
    """
    arr = np.asarray(arr)
    shifted = np.full_like(arr, pad_value)

    if shift > 0:
        shifted[shift:] = arr[:-shift]
    elif shift < 0:
        shifted[:shift] = arr[-shift:]
    else:
        shifted[:] = arr

    return shifted
 
 
PIXEL_SHIFTS = {name: pixel_shift(w) for name, w in METAL_LINES.items()}
METAL_NAMES = list(METAL_LINES.keys())
N_METALS = len(METAL_NAMES)
print(PIXEL_SHIFTS)
# Out:
# {'MgI(2853)': -180}

# %% [markdown]
# #### 2. I/O — adapt to quickquasars outputs

# %%
base_path = '/pscratch/sd/m/mherbold/tests/metal_CNN_test/QQ_output_test/QQ_output_M-only-preproc'

uncontaminated = f'{base_path}/UNCONTAMINATED-1e5/spectra.fits'
contaminated = f'{base_path}/METAL_TEST_MgI-TEMP-1e5/spectra.fits'
# contaminated = f'{base_path}/METAL_TEST_MgI-TEMP-4/spectra.fits'

fitsio.FITS(contaminated)
# Out:
#   file: /pscratch/sd/m/mherbold/tests/metal_CNN_test/QQ_output_test/QQ_output_M-only-preproc/METAL_TEST_MgI-TEMP-1e5/spectra.fits
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU
#   1      BINARY_TBL      FIBERMAP
#   2      IMAGE_HDU       B_WAVELENGTH
#   3      IMAGE_HDU       B_FLUX
#   4      IMAGE_HDU       B_IVAR
#   5      IMAGE_HDU       B_MASK
#   6      IMAGE_HDU       R_WAVELENGTH
#   7      IMAGE_HDU       R_FLUX
#   8      IMAGE_HDU       R_IVAR
#   9      IMAGE_HDU       R_MASK
#   10     IMAGE_HDU       Z_WAVELENGTH
#   11     IMAGE_HDU       Z_FLUX
#   12     IMAGE_HDU       Z_IVAR
#   13     IMAGE_HDU       Z_MASK

# %%
import desispec.io
import fitsio
 
TRUTH_FILENAME = "truth-16-12.fits" 
 
 
def read_arm_concat(spectra_path, targetid, spectra_obj=None):
    """
    Read+concatenate the B/R/Z arms for one TARGETID from a quickquasars
    spectra.fits file. Drops masked / non-positive-ivar pixels.
    Pass a pre-loaded `spectra_obj` (from desispec.io.read_spectra) to avoid
    re-reading the file for every target when looping over many TARGETIDs
    from the same file.
    """
    spectra = spectra_obj if spectra_obj is not None else desispec.io.read_spectra(spectra_path)
    tids = spectra.fibermap["TARGETID"]
    matches = np.where(np.asarray(tids) == targetid)[0]
    if len(matches) == 0:
        raise ValueError(f"TARGETID {targetid} not found in {spectra_path}")
    idx = matches[0]
 
    waves, fluxes, ivars = [], [], []
    for band in ["b", "r", "z"]:
        wave = spectra.wave[band]
        flux = spectra.flux[band][idx]
        ivar = spectra.ivar[band][idx]
        mask = spectra.mask[band][idx] if spectra.mask is not None else np.zeros_like(flux, dtype=int)
        good = (mask == 0) & (ivar > 0)
        waves.append(wave[good])
        fluxes.append(flux[good])
        ivars.append(ivar[good])
 
    wave_obs = np.concatenate(waves)
    flux = np.concatenate(fluxes)
    ivar = np.concatenate(ivars)
    order = np.argsort(wave_obs)
    # NOTE: b/r/z arms overlap slightly at their edges, so the concatenated
    # array isn't perfectly monotonic-unique there -- fine for interp1d used
    # below, but if you need a proper coadd in the overlap region later,
    # desispec has coaddition utilities for that.
    return wave_obs[order], flux[order], ivar[order]
 
 
def get_common_targetids(path_a, path_b):
    """TARGETIDs present in both the contaminated and uncontaminated files."""
    tid_a = fitsio.FITS(path_a)["FIBERMAP"].read(columns=["TARGETID"])["TARGETID"]
    tid_b = fitsio.FITS(path_b)["FIBERMAP"].read(columns=["TARGETID"])["TARGETID"]
    return np.intersect1d(tid_a, tid_b)
 
 
def read_arm_concat_raw(spectra_path, targetid, spectra_obj=None):
    """
    Like read_arm_concat, but does NOT drop masked pixels -- returns the FULL
    fixed instrument wavelength grid (same length/values for every target on
    the same instrument setup). Needed so that the contaminated and
    uncontaminated exposures of the same TARGETID line up pixel-for-pixel
    without any interpolation, which matters for the shared-continuum trick
    in build_paired_sample below.
    """
    spectra = spectra_obj if spectra_obj is not None else desispec.io.read_spectra(spectra_path)
    tids = spectra.fibermap["TARGETID"]
    matches = np.where(np.asarray(tids) == targetid)[0]
    if len(matches) == 0:
        raise ValueError(f"TARGETID {targetid} not found in {spectra_path}")
    idx = matches[0]
 
    waves, fluxes, ivars, masks = [], [], [], []
    for band in ["b", "r", "z"]:
        wave = spectra.wave[band]
        flux = spectra.flux[band][idx]
        ivar = spectra.ivar[band][idx]
        mask = spectra.mask[band][idx] if spectra.mask is not None else np.zeros_like(flux, dtype=int)
        waves.append(wave)
        fluxes.append(flux)
        ivars.append(ivar)
        masks.append(mask)
 
    wave_obs = np.concatenate(waves)
    flux = np.concatenate(fluxes)
    ivar = np.concatenate(ivars)
    mask = np.concatenate(masks)
    order = np.argsort(wave_obs)
    return wave_obs[order], flux[order], ivar[order], mask[order]
 
 
def read_ztrue(spectra_path, targetid):
    """Pull Z_true for this TARGETID from the companion truth file."""
    truth_path = os.path.join(os.path.dirname(spectra_path), TRUTH_FILENAME)
    truth = fitsio.FITS(truth_path)["TRUTH"].read(columns=["TARGETID", "Z"])
    row = truth[truth["TARGETID"] == targetid]
    if len(row) == 0:
        raise ValueError(f"TARGETID {targetid} not in truth file {truth_path}")
    return float(row["Z"][0])

# %% [markdown]
# #### 3. Preprocessing: continuum normalize + resample to fixed rest-frame grid + add channels

# %%
def continuum_normalize(wave_obs, flux, ivar, z_qso, smooth_pix=150):
    """
    Superseded by the shared-continuum logic inside build_paired_sample --
    normalizing a single noisy exposure independently (as this function
    does) gives each exposure a DIFFERENT noisy continuum estimate, which
    then does NOT cancel in the flux_c/flux_u ratio and leaks noise/bias
    straight into the metal-line label. Left here only as a building block
    if you need to continuum-normalize a single spectrum outside the paired
    pipeline (e.g. for visualizing one exposure on its own).
    """
    from scipy.ndimage import median_filter
    cont = median_filter(flux, size=smooth_pix, mode="nearest")
    cont[cont <= 0] = np.nan
    norm_flux = flux / cont
    norm_ivar = ivar * cont ** 2
    return norm_flux, norm_ivar
 
 
def to_restframe_grid(wave_obs, flux, ivar, z_qso):
    """Resample onto the fixed N_PIX log-lambda grid in the quasar rest frame."""
    rest_wave = wave_obs / (1.0 + z_qso)
    sel = (rest_wave > FOREST_MIN) & (rest_wave < FOREST_MAX) & np.isfinite(flux)
    if sel.sum() < 10:
        return None
    f_interp = interp1d(rest_wave[sel], flux[sel], bounds_error=False, fill_value=1.0)
    iv_interp = interp1d(rest_wave[sel], ivar[sel], bounds_error=False, fill_value=0.0)
    flux_grid = f_interp(REST_GRID)
    ivar_grid = iv_interp(REST_GRID)
    return flux_grid, ivar_grid
 
 
def make_shifted_channels(flux_grid):
    """One extra input channel per metal transition: the forest pattern that
    would echo into that transition's absorption, aligned pixel-for-pixel."""
    channels = []
    for name in METAL_NAMES:
        shift = PIXEL_SHIFTS[name]
        shifted = np.roll(flux_grid, -shift)
        # pad the wrapped-around edge with continuum level (1.0) so it doesn't
        # masquerade as a real feature
        if shift > 0:
            shifted[-shift:] = 1.0
        elif shift < 0:
            shifted[:-shift] = 1.0
        channels.append(shifted)
    return np.stack(channels, axis=0)  # (N_METALS, N_PIX)

# %%
# add Lyman Alpha absorption channel

# LYA_REST = 1215.67
LYA_MIN = 1040.0
LYA_MAX = 1200.0

# binary lya channel (yes / no forest region)
def make_lya_binary_channel(rest_grid, lya_min=1040.0, lya_max=1200.0):
    """
    Binary mask indicating pixels in the Lyα forest rest-frame region.
    """
    return (
        (rest_grid >= lya_min) &
        (rest_grid <= lya_max)
    ).astype(np.float32)

# # continuous lya channel (apparent absorption / transmission in region)
# def make_lya_structure_channel(flux_grid, sigma_pix=1.0):
#     """
#     Smooth apparent optical-depth structure in the Lyα forest.

#     Outside the Lyα forest, set the channel to zero.
#     """

#     flux_safe = np.clip(flux_grid, 1e-3, None)

#     tau = -np.log(flux_safe)

#     tau_smooth = gaussian_filter1d(
#         tau,
#         sigma=sigma_pix,
#         mode="nearest",
#     )

#     lya_mask = (
#         (REST_GRID >= LYA_MIN) &
#         (REST_GRID <= LYA_MAX)
#     )

#     channel = np.zeros_like(flux_grid, dtype=np.float32)

#     channel[lya_mask] = tau_smooth[lya_mask]

#     return channel.astype(np.float32)

# %%
# # add metal absorption region mask

# def make_absorber_z_channel(z_qso, rest_grid, metal_wave):
#     z_abs = (
#         rest_grid * (1 + z_qso) / metal_wave
#     ) - 1.0

#     # Scale approximately to [-1, 1] over the useful range
#     return z_abs.astype(np.float32)

# %% [markdown]
# #### 4. Labels: per-pixel, per-transition metal optical depth

# %%
def build_paired_sample(targetid, uncontam_path, contam_path,
                         spectra_uncontam=None, spectra_contam=None,
                         cont_smooth_pix=150):
    """
    Build one training sample from the contaminated / uncontaminated spectra
    for a single TARGETID. Returns None if the forest window isn't covered.
 
    Continuum handling: rather than normalizing each exposure independently
    (which was giving a noisy continuum estimate on EACH side, and since the
    two estimates then differ, that noise doesn't cancel in the flux_c/flux_u
    ratio -- it leaks straight into the metal-line label as spurious
    scatter), we estimate ONE continuum from the average of both exposures
    (halves the noise going into the fit) and divide both sides by that SAME
    continuum. Any residual continuum-fit error or shape then cancels
    exactly in the ratio -- it only affects the overall normalization scale
    of the CNN input, not the label.
    """
    wave_u, flux_u, ivar_u, mask_u = read_arm_concat_raw(uncontam_path, targetid, spectra_uncontam)
    wave_c, flux_c, ivar_c, mask_c = read_arm_concat_raw(contam_path, targetid, spectra_contam)
    z_qso = read_ztrue(uncontam_path, targetid)
 
    if not np.array_equal(wave_u, wave_c):
        raise RuntimeError(
            f"wavelength grids differ between contaminated/uncontaminated "
            f"spectra for TARGETID {targetid} -- unexpected for the same "
            f"instrument setup/target; check that both files really share "
            f"the same fiber/exposure layout."
        )
    wave_obs = wave_u
 
    good = (mask_u == 0) & (mask_c == 0) & (ivar_u > 0) & (ivar_c > 0)
    if good.sum() < 20:
        return None
 
    from scipy.ndimage import median_filter
    avg_flux = 0.5 * (flux_u + flux_c)
    # fill masked/bad pixels for continuum-fitting purposes only, so the
    # median filter doesn't get corrupted by garbage values in masked gaps
    idx_good = np.where(good)[0]
    filled = np.interp(np.arange(len(avg_flux)), idx_good, avg_flux[idx_good])
    cont = median_filter(filled, size=cont_smooth_pix, mode="nearest")
    cont[cont <= 0] = np.nan
 
    flux_u_norm = flux_u / cont
    flux_c_norm = flux_c / cont
    ivar_u_norm = ivar_u * cont ** 2
    ivar_c_norm = ivar_c * cont ** 2
    ivar_u_norm[~good] = 0.0
    ivar_c_norm[~good] = 0.0
 
    grid_u = to_restframe_grid(wave_obs, flux_u_norm, ivar_u_norm, z_qso)
    grid_c = to_restframe_grid(wave_obs, flux_c_norm, ivar_c_norm, z_qso)
    if grid_u is None or grid_c is None:
        return None
    flux_u_grid, ivar_u_grid = grid_u
    flux_c_grid, ivar_c_grid = grid_c
 
    # network input is the *contaminated* (realistic) spectrum; label is the
    # metal-only optical depth recovered by differencing against the
    # metal-free twin. `weight` propagates BOTH exposures' noise (see
    # build_label_maps) since you only have one realization per side -- this
    # is what the training loss uses, not raw `ivar_c_grid`.
    label, weight = build_label_maps(flux_c_grid, flux_u_grid, ivar_c_grid, ivar_u_grid)
    return {
        "flux": flux_c_grid,
        "ivar": ivar_c_grid,
        "label": label,
        "weight": weight,
        "targetid": targetid,
        "z_qso": z_qso,
    }
 
 
def check_shared_noise_realization(targetid, uncontam_path, contam_path, n_show=5):
    """
    Diagnostic: if the two files DON'T share a noise realization (common for
    quickquasars -- the noise seed is often independent of the seed used for
    the density field / metal strengths / templates), the flux difference
    away from the metal feature will be consistent with the FULL per-pixel
    noise amplitude rather than ~0. If that's what you see, don't difference
    single pairs -- average many noise realizations first (see
    `build_averaged_pair_grids` below) before differencing.
    """
    wave_u, flux_u, ivar_u = read_arm_concat(uncontam_path, targetid)
    wave_c, flux_c, ivar_c = read_arm_concat(contam_path, targetid)
    z_qso = read_ztrue(uncontam_path, targetid)
 
    diff = flux_c - np.interp(wave_u, wave_u, flux_u)  # same grid check below is more robust
    rest = wave_u / (1 + z_qso)
    away = np.abs(rest - 1304.37) > 5  # Angstrom, away from the SiII(1304) feature
    std_diff = np.nanstd(diff[away])
    typical_noise = np.nanmedian(1 / np.sqrt(ivar_u[away]))
    print(f"TARGETID {targetid}: std(diff) away from line = {std_diff:.4f}, "
          f"typical 1/sqrt(ivar) = {typical_noise:.4f}, ratio = {std_diff/typical_noise:.2f}")
    print("  -> ratio near 0     : noise IS shared -- single-pair differencing is clean.")
    print("  -> ratio near 1.4   : noise is INDEPENDENT (sqrt(2) x single-exposure noise) -- average realizations.")
    return std_diff, typical_noise
 
 
def build_averaged_pair_grids(targetid, uncontam_paths, contam_paths):
    """
    NOT APPLICABLE to your current data (single realization per side) --
    kept here in case you're able to generate repeated noise draws of the
    same skewers later, which would let you build much cleaner labels than
    the single-pair-with-propagated-weights approach used below.
 
    uncontam_paths / contam_paths: lists of spectra.fits paths, each a
    DIFFERENT noise realization of the SAME underlying skewer/target (same
    density-field/metals/template seed, only the noise draw differs). Averages
    (ivar-weighted, i.e. inverse-variance stacked) the resampled flux across
    realizations separately for the contaminated and uncontaminated sets --
    this denoises each set toward its noiseless flux -- then differences the
    two *stacked* spectra for a much cleaner metal-only label than any single
    pair would give.
    """
    def stack(paths):
        num = np.zeros(N_PIX)
        den = np.zeros(N_PIX)
        z_qso = None
        for p in paths:
            wave, flux, ivar = read_arm_concat(p, targetid)
            if z_qso is None:
                z_qso = read_ztrue(p, targetid)
            fnorm, ivnorm = continuum_normalize(wave, flux, ivar, z_qso)
            grid = to_restframe_grid(wave, fnorm, ivnorm, z_qso)
            if grid is None:
                continue
            fg, ivg = grid
            ivg = np.nan_to_num(ivg, nan=0.0)
            fg = np.nan_to_num(fg, nan=1.0)
            num += fg * ivg
            den += ivg
        stacked_flux = np.divide(num, den, out=np.ones_like(num), where=den > 0)
        stacked_ivar = den
        return stacked_flux, stacked_ivar, z_qso
 
    flux_u, ivar_u, z_qso = stack(uncontam_paths)
    flux_c, ivar_c, _ = stack(contam_paths)
    label, weight = build_label_maps(flux_c, flux_u, ivar_c, ivar_u)
    return flux_c, ivar_c, label, weight, z_qso
 
 
def build_label_maps(flux_with, flux_without, ivar_with, ivar_without):
    """
    Returns (labels, weight) both shaped (N_METALS, N_PIX).
 
    labels: metal-only signal as a LINEAR flux difference,
        dF = flux_without - flux_with   (positive where metals add absorption)
    Deliberately NOT log optical depth (-log(flux_with/flux_without)): that
    involves a division and a log, both of which blow up whenever either
    exposure's flux noise-dips near zero -- routine at low S/N (e.g. camera
    edges near wmin/wmax, arm-overlap gaps). Those blow-ups show up as fixed-
    height "clipped ceiling" spikes at specific wavelengths that have nothing
    to do with real absorption and will swamp genuine, weak metal features.
    A linear difference has no such singularity -- it's just noisy where the
    data are noisy, which the `weight` map below already accounts for.
    For the weak realistic line strengths of interest (tau ~ 1e-4) and
    continuum-normalized flux ~1, dF ~= tau anyway, so this is an equally
    valid regression target, just numerically well-behaved. extract_lines'
    "strength" is accordingly an EW-like linear quantity now, not tau.
 
    weight: inverse-variance to use for the LOSS, not just IO's `ivar`. The
    label is a *difference* of two independently-noisy exposures, so its
    variance is the SUM of both exposures' variances:
        var(dF) ~ 1/ivar_with + 1/ivar_without
    Using only ivar_with here would understate how noisy the label really is
    by up to a factor of 2, and bias the network toward trusting noisy
    labels too much (this matters a lot with a single realization per side,
    per your setup -- there's no averaging-down of label noise otherwise).
    """
    dF_total = flux_without - flux_with
 
    good = (ivar_with > 0) & (ivar_without > 0)
    combined_ivar = np.zeros_like(ivar_with)
    combined_ivar[good] = 1.0 / (1.0 / ivar_with[good] + 1.0 / ivar_without[good])
    dF_total[~good] = 0.0
 
    labels = np.zeros((N_METALS, N_PIX), dtype=np.float32)
    weight = np.zeros((N_METALS, N_PIX), dtype=np.float32)
    for i, name in enumerate(METAL_NAMES):
        # tau_metal for transition m sits at the SAME pixel as tau_total here,
        # since tau_total already lives on the observed/rest grid where the
        # metal absorption actually appears (no re-shifting needed for labels
        # -- the shift is only needed to build the *input* echo feature).
        labels[i] = dF_total
        weight[i] = combined_ivar
    return labels, weight  # NOTE: if injecting multiple metals simultaneously,
    # you'll want separate paired runs (metals one at a time) to get clean
    # per-species labels, or use the true per-species tau from the
    # transmission file if your quickquasars setup exposes it.

# %% [markdown]
# #### 5. Dataset

# %%
# class MetalLineDataset(Dataset):
#     def __init__(self, samples):
#         """
#         samples: list of dicts, each with keys
#             'flux' (N_PIX,), 'ivar' (N_PIX,), 'label' (N_METALS, N_PIX)
#         """
#         self.samples = samples
 
#     def __len__(self):
#         return len(self.samples)
 
#     def __getitem__(self, idx):
#         s = self.samples[idx]
    
#         flux = s["flux"].astype(np.float32)
#         ivar = s["ivar"].astype(np.float32)
    
#         # Normalize inverse variance for use as a CNN input
#         IVAR_SCALE = 1e7
#         ivar = ivar / IVAR_SCALE    
#         # ivar = np.log1p(ivar)
#         # ivar = ivar / (np.mean(ivar) + 1e-8)
    
#         shifted = make_shifted_channels(flux).astype(np.float32)
    
#         x = np.concatenate(
#             [flux[None, :], ivar[None, :], shifted],
#             axis=0
#         )
    
#         y = s["label"].astype(np.float32)
#         w = s["weight"].astype(np.float32)
    
#         return torch.from_numpy(x), torch.from_numpy(y), torch.from_numpy(w)

# %%
def build_detection_targets(labels, min_peak=0.01, sigma_pix=1.5, distance=3):
    """
    Turn the continuous, sparse dF label (N_METALS, N_PIX) into a soft
    per-pixel detection heatmap (N_METALS, N_PIX) in [0, 1]: a small
    Gaussian bump centered on each true peak.

    A hard 0/1 target also works, but the soft Gaussian gives the
    classifier partial credit for being "close" during training, which
    speeds up convergence when peak positions only matter to within a
    few pixels (as they do here downstream in match_detections_v2).

    min_peak: same absolute threshold you already use elsewhere
        (extract_lines_v4 uses min_peak_tau=0.001-0.01) -- keep these
        consistent so "what counts as a real line" doesn't silently
        differ between label-building and evaluation.
    """

    n_metals, n_pix = labels.shape
    heatmap = np.zeros((n_metals, n_pix), dtype=np.float32)
    xs = np.arange(n_pix)

    for i in range(n_metals):
        tau = labels[i]
        if tau.max() < min_peak:
            continue
        peaks, _ = find_peaks(tau, height=min_peak, distance=distance)
        for p in peaks:
            heatmap[i] = np.maximum(
                heatmap[i],
                np.exp(-0.5 * ((xs - p) / sigma_pix) ** 2),
            )

    return heatmap

# %%
class MetalLineDatasetV2(Dataset):
    """
    Same as MetalLineDataset, but __getitem__ also returns the binary/soft
    detection target built from the true label, for the two-head model.
    """
    def __init__(self, samples, min_peak=0.01, sigma_pix=1.0):
                 # sigma_pix=1.5):
        
        self.samples = samples
        self.min_peak = min_peak
        self.sigma_pix = sigma_pix
        
        # Binary Lyα forest indicator on the fixed rest-frame grid
        self.lya_mask = make_lya_binary_channel(REST_GRID)

        # metal absorber boundary / coordinate
        # self.z_abs = make_absorber_z_channel(
        #     z_qso, 
        #     REST_GRID, 
        #     # METAL_LINES,
        #     METAL_LINES["MgI(2853)"],
        # )

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        s = self.samples[idx]

        flux = s["flux"].astype(np.float32)
        ivar = s["ivar"].astype(np.float32)

        IVAR_SCALE = 1e7
        ivar = ivar / IVAR_SCALE

        shifted = make_shifted_channels(flux).astype(np.float32)

        # continuous Lya forest grid
        # lya_structure = make_lya_structure_channel(flux)

        x = np.concatenate([flux[None, :], 
                            ivar[None, :], 
                            shifted, 
                            self.lya_mask[None, :],
                            # self.z_abs[None, :],
                            # lya_structure[None,:]
                           ], 
                           axis=0)

        y_strength = s["label"].astype(np.float32)
        w = s["weight"].astype(np.float32)
        y_detect = build_detection_targets(
            y_strength, 
            min_peak=self.min_peak, 
            sigma_pix=self.sigma_pix
        )

        return (
            torch.from_numpy(x),
            torch.from_numpy(y_detect),
            torch.from_numpy(y_strength),
            torch.from_numpy(w),
        )


# train_loader_v2 = DataLoader(MetalLineDatasetV2(train_samples), batch_size=32, shuffle=True)
# val_loader_v2 = DataLoader(MetalLineDatasetV2(val_samples), batch_size=32, shuffle=False)

# %%
base_path = "/pscratch/sd/m/mherbold/tests/metal_CNN_test/QQ_output_test/QQ_output_M-only-preproc"

uncontaminated_path = uncontaminated
contaminated_path = contaminated
 
common_ids = get_common_targetids(uncontaminated_path, contaminated_path)
std_diff, typical_noise = check_shared_noise_realization(common_ids[0], uncontaminated_path, contaminated_path)
 
# Load each spectra.fits ONCE, then reuse for every TARGETID 
spectra_uncontam = desispec.io.read_spectra(uncontaminated_path)
spectra_contam = desispec.io.read_spectra(contaminated_path)
 
samples = []
for tid in common_ids:
    try:
        s = build_paired_sample(
            tid, uncontaminated_path, contaminated_path,
            spectra_uncontam=spectra_uncontam, spectra_contam=spectra_contam,
        )
    except Exception as e:
        print(f"skipping TARGETID {tid}: {e}")
        continue
    if s is not None:
        samples.append(s)
 
print(f"built {len(samples)} / {len(common_ids)} samples")
 
# split by TARGETID so train/val don't leak
rng = np.random.default_rng(0)
idx = rng.permutation(len(samples))
n_val = max(1, int(0.15 * len(samples)))
val_samples = [samples[i] for i in idx[:n_val]]
train_samples = [samples[i] for i in idx[n_val:]]
 
train_loader_v2 = DataLoader(MetalLineDatasetV2(train_samples), batch_size=32, shuffle=True)
val_loader_v2 = DataLoader(MetalLineDatasetV2(val_samples), batch_size=32, shuffle=False)
# Out:
# INFO:spectra.py:453:read_spectra: iotime 0.032 sec to read spectra from:  spectra.fits at 2026-08-18T13:05:49.893372
# INFO:spectra.py:453:read_spectra: iotime 0.032 sec to read spectra from:  spectra.fits at 2026-08-18T13:05:49.938283
# TARGETID 1001: std(diff) away from line = 0.0254, typical 1/sqrt(ivar) = 0.0011, ratio = 23.17
#   -> ratio near 0     : noise IS shared -- single-pair differencing is clean.
#   -> ratio near 1.4   : noise is INDEPENDENT (sqrt(2) x single-exposure noise) -- average realizations.
# INFO:spectra.py:453:read_spectra: iotime 0.035 sec to read spectra from:  spectra.fits at 2026-08-18T13:05:49.998960
# INFO:spectra.py:453:read_spectra: iotime 0.033 sec to read spectra from:  spectra.fits at 2026-08-18T13:05:50.042015
# built 137 / 137 samples

# %% [markdown]
# #### 6. Model

# %%
# class MetalCNN(nn.Module):
#     def __init__(self, in_channels, n_metals, hidden=64):
#         super().__init__()

#         self.net = nn.Sequential(
#             nn.Conv1d(in_channels, hidden, kernel_size=7, padding=3),
#             nn.LeakyReLU(0.01),

#             nn.Conv1d(hidden, hidden, kernel_size=5, padding=2),
#             nn.LeakyReLU(0.01),

#             nn.Conv1d(hidden, hidden, kernel_size=5, padding=2),
#             nn.LeakyReLU(0.01),

#             nn.Conv1d(hidden, n_metals, kernel_size=3, padding=1),
#         )

#     def forward(self, x):
#         return self.net(x)

# model = MetalCNN(in_channels=2 + N_METALS, n_metals=N_METALS)

# %%
class TwoHeadMetalCNN(nn.Module):
    def __init__(self, in_channels, n_metals, hidden=64):
        super().__init__()

        self.trunk = nn.Sequential(
            nn.Conv1d(
                in_channels, hidden,
                kernel_size=7,
                padding=3,
                padding_mode="replicate",
            ),
            nn.LeakyReLU(0.01),
        
            nn.Conv1d(
                hidden, hidden,
                kernel_size=5,
                padding=2,
                padding_mode="replicate",
            ),
            nn.LeakyReLU(0.01),
        
            nn.Conv1d(
                hidden, hidden,
                kernel_size=5,
                padding=2,
                padding_mode="replicate",
            ),
            nn.LeakyReLU(0.01),
        
            nn.Conv1d(
                hidden, hidden,
                kernel_size=5,
                padding=2,
                padding_mode="replicate",
            ),
            nn.LeakyReLU(0.01),
        )
        # raw logits -- apply sigmoid outside (BCEWithLogits-style) for
        # numerical stability
        self.detect_head = nn.Conv1d(
            hidden,
            n_metals,
            kernel_size=3,
            padding=1,
            padding_mode="replicate",
        )
        self.strength_head = nn.Conv1d(
            hidden,
            n_metals,
            kernel_size=3,
            padding=1,
            padding_mode="replicate",
        )

    def forward(self, x):
        feat = self.trunk(x)
        detect_logits = self.detect_head(feat)
        strength = self.strength_head(feat)
        return detect_logits, strength


# model = TwoHeadMetalCNN(in_channels = 2 + N_METALS, n_metals=N_METALS)

model = TwoHeadMetalCNN(in_channels = 3 + N_METALS, n_metals=N_METALS)

# %% [markdown]
# #### 7. Loss + training loop

# %%
# # def masked_weighted_mse(pred, target, weight, l1_sparsity=1e-4):
# #     se = (pred - target) ** 2 * weight
# #     mse = se.sum() / (weight.sum() + 1e-8)
# #     # sparsity = l1_sparsity * pred.mean()  # discourages spurious everywhere-detections
# #     # return mse + sparsity
# #     return mse

# def masked_weighted_mse(pred, target, weight, l1_sparsity=1e-5):
#     se = (pred - target) ** 2 * weight
#     mse = se.sum() / (weight.sum() + 1e-8)

#     positive_pred = torch.relu(pred)
#     sparsity = l1_sparsity * positive_pred.mean()

#     return mse + sparsity

# %%
def focal_bce_loss(logits, target, alpha=0.85, gamma=2.0):
    """
    Focal loss (Lin et al. 2017) on top of BCE-with-logits. `alpha` up-
    weights the rare positive (on-a-line) class; `gamma` down-weights
    already-easy examples (both confidently-correct negatives AND
    confidently-correct positives) so the loss stays focused on the hard,
    ambiguous pixels near line edges instead of being swamped by the vast
    number of trivially-easy background pixels.
    """
    prob = torch.sigmoid(logits)
    prob = prob.clamp(1e-6, 1 - 1e-6)

    bce = -(alpha * target * torch.log(prob)
            + (1 - alpha) * (1 - target) * torch.log(1 - prob))
    focal_weight = (target * (1 - prob) + (1 - target) * prob) ** gamma
    return (focal_weight * bce).mean()
    

# def detection_loss(logits, target, pos_weight=10.0):
#     # Pixelwise weighting based on soft target.
#     # target=1 gets pos_weight; target=0 gets weight 1.
#     weights = 1.0 + (pos_weight - 1.0) * target

#     loss = F.binary_cross_entropy_with_logits(
#         logits,
#         target,
#         reduction="none",
#     )
#     return (weights * loss).mean()

def detection_loss(logits, target, pos_weight=10.0):
    weights = 1.0 + (pos_weight - 1.0) * target

    bce = torch.nn.functional.binary_cross_entropy_with_logits(
    # bce = F.binary_cross_entropy_with_logits(
        logits,
        target,
        reduction="none",
    )

    return (weights * bce).mean()

def masked_strength_loss(
    strength_pred,
    strength_true,
    weight,
    min_strength=0.01,
):
    mask = (strength_true >= min_strength).float()
    weighted_mask = mask * weight
    se = (strength_pred - strength_true) ** 2 * weighted_mask

    return se.sum() / (weighted_mask.sum() + 1e-8)


# def combined_loss(detect_logits, strength_pred, detect_target, strength_true,
#                    weight, lambda_strength=1.0, alpha=0.85, gamma=2.0):
#     l_detect = focal_bce_loss(detect_logits, detect_target, alpha=alpha, gamma=gamma)
#     l_strength = masked_strength_loss(strength_pred, strength_true, detect_target, weight)
#     total = l_detect + lambda_strength * l_strength
#     return total, l_detect.detach().item(), l_strength.detach().item()


def combined_loss(
    detect_logits,
    strength_pred,
    detect_target,
    strength_true,
    weight,
    lambda_strength=1.0,
    pos_weight=10.0,
    # pos_weight=5.0,
):
    l_detect = detection_loss(
        detect_logits,
        detect_target,
        pos_weight=pos_weight,
    )

    l_strength = masked_strength_loss(
        strength_pred,
        strength_true,
        weight,
    )

    total = l_detect + lambda_strength * l_strength

    return total, l_detect.detach().item(), l_strength.detach().item()

# %%
# def train(model, train_loader, val_loader, epochs=30, lr=1e-3, device="cpu"):
#     model.to(device)
#     opt = torch.optim.Adam(model.parameters(), lr=lr)
#     sched = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, patience=3, factor=0.5)
#     best_val = np.inf
#     for epoch in range(epochs):
#         model.train()
#         train_loss = 0.0
#         for x, y, w in train_loader:
#             x, y, w = x.to(device), y.to(device), w.to(device)
#             opt.zero_grad()
#             pred = model(x)
#             # pred = torch.ReLU(model(x))
#             loss = masked_weighted_mse(pred, y, w)
#             loss.backward()
            
#             torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

#             if epoch == 0:
#                 print(
#                     "final layer gradient:",
#                     model.net[-1].weight.grad.abs().mean().item()
#                 )
            
#             opt.step()
#             train_loss += loss.item() * x.size(0)
        
#         train_loss /= len(train_loader.dataset)
 
#         model.eval()
#         val_loss = 0.0
#         with torch.no_grad():
#             raw = model(x)
#             for x, y, w in val_loader:
#                 x, y, w = x.to(device), y.to(device), w.to(device)
#                 pred = model(x)
#                 # pred = torch.relu(model(x))
#                 val_loss += masked_weighted_mse(pred, y, w).item() * x.size(0)
#         print(
#                 "raw:",
#                 raw.min().item(),
#                 raw.max().item(),
#                 raw.mean().item()
#             )
#         val_loss /= len(val_loader.dataset)
#         sched.step(val_loss)
 
#         print(f"epoch {epoch:3d}  train {train_loss:.5f}  val {val_loss:.5f}")
#         if val_loss < best_val:
#             best_val = val_loss
#             torch.save(model.state_dict(), "best_metal_cnn.pt")

#     return model

# %%
def train_two_head(model, train_loader, val_loader, epochs=60, lr=1e-3,
                    device="cpu", lambda_strength=1.0, alpha=0.85, gamma=2.0):
    """
    NOTE the learning rate: the original run used lr=1e-5 for 30 epochs,
    and the training-loss trace barely moved (0.0119 -> 0.0106) -- far
    from converged. 1e-3 (Adam's usual starting point) with a
    ReduceLROnPlateau scheduler gets you into the right regime much
    faster; the scheduler will back it off automatically if it overshoots.
    """
    model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    sched = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, patience=3, factor=0.5)
    best_val = np.inf

    for epoch in range(epochs):
        model.train()
        train_loss = train_ld = train_ls = 0.0
        for x, y_detect, y_strength, w in train_loader:
            x = x.to(device)
            y_detect, y_strength, w = y_detect.to(device), y_strength.to(device), w.to(device)

            opt.zero_grad()
            detect_logits, strength_pred = model(x)
            
            # loss, ld, ls = combined_loss(
            #     detect_logits, strength_pred, y_detect, y_strength, w,
            #     lambda_strength=lambda_strength, alpha=alpha, gamma=gamma)

            loss, ld, ls = combined_loss(
                detect_logits, strength_pred, y_detect, y_strength, 
                w, lambda_strength=lambda_strength)
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            opt.step()

            bs = x.size(0)
            train_loss += loss.item() * bs
            train_ld += ld * bs
            train_ls += ls * bs

        n_train = len(train_loader.dataset)
        train_loss /= n_train
        train_ld /= n_train
        train_ls /= n_train

        model.eval()
        val_loss = val_ld = val_ls = 0.0
        with torch.no_grad():
            for x, y_detect, y_strength, w in val_loader:
                x = x.to(device)
                y_detect, y_strength, w = y_detect.to(device), y_strength.to(device), w.to(device)
                detect_logits, strength_pred = model(x)
                # loss, ld, ls = combined_loss(
                #     detect_logits, strength_pred, y_detect, y_strength, w,
                #     lambda_strength=lambda_strength, alpha=alpha, gamma=gamma,
                # )
                loss, ld, ls = combined_loss(
                    detect_logits, strength_pred, y_detect, y_strength, 
                    w, lambda_strength=lambda_strength)
                bs = x.size(0)
                val_loss += loss.item() * bs
                val_ld += ld * bs
                val_ls += ls * bs

        n_val = len(val_loader.dataset)
        val_loss /= n_val
        val_ld /= n_val
        val_ls /= n_val
        sched.step(val_loss)

        print(f"epoch {epoch:3d}  train {train_loss:.5f} (det {train_ld:.5f} / str {train_ls:.5f})"
              f"  val {val_loss:.5f} (det {val_ld:.5f} / str {val_ls:.5f})")

        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), "two_head_metal_cnn.pt")

    return model

# %%
# # check that channel weights are reasonable / normalized

# x, y, w = next(iter(train_loader))

# for c in range(x.shape[1]):
#     print(
#         f"channel {c}: "
#         f"min={x[:,c,:].min():.4f}, "
#         f"max={x[:,c,:].max():.4f}, "
#         f"mean={x[:,c,:].mean():.4f}, "
#         f"std={x[:,c,:].std():.4f}"
#     )

# %% [markdown]
# #### 7.1 train model

# %%
model = train_two_head(
    model, train_loader_v2, val_loader_v2, epochs=30, lr=1e-3, device=device,
)

model.load_state_dict(torch.load("two_head_metal_cnn.pt", map_location=device))
model.eval()
# Out:
# epoch   0  train 1.11011 (det 1.07376 / str 0.03635)  val 0.98626 (det 0.91143 / str 0.07483)
# epoch   1  train 0.82458 (det 0.77348 / str 0.05110)  val 0.88673 (det 0.80081 / str 0.08591)
# epoch   2  train 0.71112 (det 0.68411 / str 0.02702)  val 1.17702 (det 0.68346 / str 0.49357)
# epoch   3  train 0.67273 (det 0.63900 / str 0.03373)  val 1.51095 (det 0.71156 / str 0.79939)
# epoch   4  train 0.63703 (det 0.60889 / str 0.02813)  val 1.24217 (det 0.64972 / str 0.59245)
# epoch   5  train 0.59158 (det 0.57320 / str 0.01838)  val 0.88588 (det 0.60993 / str 0.27595)
# epoch   6  train 0.57803 (det 0.56141 / str 0.01662)  val 0.88500 (det 0.61448 / str 0.27052)
# epoch   7  train 0.57737 (det 0.55567 / str 0.02170)  val 1.10307 (det 0.58141 / str 0.52167)
# epoch   8  train 0.55317 (det 0.53399 / str 0.01918)  val 0.86505 (det 0.54874 / str 0.31631)
# epoch   9  train 0.52702 (det 0.51206 / str 0.01496)  val 0.85220 (det 0.55247 / str 0.29973)
# epoch  10  train 0.51137 (det 0.50079 / str 0.01059)  val 0.82348 (det 0.55095 / str 0.27253)
# epoch  11  train 0.51811 (det 0.50732 / str 0.01080)  val 0.75776 (det 0.54670 / str 0.21105)
# epoch  12  train 0.50223 (det 0.49144 / str 0.01079)  val 0.72647 (det 0.51921 / str 0.20726)
# epoch  13  train 0.48190 (det 0.47400 / str 0.00790)  val 0.64118 (det 0.49208 / str 0.14910)
# epoch  14  train 0.46745 (det 0.45888 / str 0.00857)  val 0.70019 (det 0.49391 / str 0.20628)
# epoch  15  train 0.46056 (det 0.45234 / str 0.00822)  val 0.57116 (det 0.49532 / str 0.07584)
# epoch  16  train 0.46046 (det 0.45038 / str 0.01008)  val 0.61403 (det 0.46604 / str 0.14799)
# epoch  17  train 0.45105 (det 0.44412 / str 0.00693)  val 0.60690 (det 0.49412 / str 0.11278)
# epoch  18  train 0.50447 (det 0.49738 / str 0.00709)  val 0.57758 (det 0.50546 / str 0.07212)
# epoch  19  train 0.47048 (det 0.46359 / str 0.00689)  val 0.63607 (det 0.49799 / str 0.13808)
# epoch  20  train 0.48625 (det 0.47946 / str 0.00679)  val 0.58591 (det 0.45869 / str 0.12722)
# epoch  21  train 0.47298 (det 0.46639 / str 0.00659)  val 0.64801 (det 0.53398 / str 0.11403)
# epoch  22  train 0.45311 (det 0.44738 / str 0.00573)  val 0.60981 (det 0.47614 / str 0.13367)
# epoch  23  train 0.44164 (det 0.43637 / str 0.00527)  val 0.57401 (det 0.48987 / str 0.08414)
# epoch  24  train 0.45313 (det 0.44662 / str 0.00651)  val 0.56320 (det 0.47504 / str 0.08816)
# epoch  25  train 0.43278 (det 0.42719 / str 0.00559)  val 0.57727 (det 0.47014 / str 0.10713)
# epoch  26  train 0.44214 (det 0.43669 / str 0.00545)  val 0.54826 (det 0.45576 / str 0.09250)
# epoch  27  train 0.42573 (det 0.42015 / str 0.00558)  val 0.55702 (det 0.46092 / str 0.09610)
# epoch  28  train 0.42346 (det 0.41853 / str 0.00492)  val 0.57404 (det 0.45279 / str 0.12125)
# epoch  29  train 0.42297 (det 0.41785 / str 0.00512)  val 0.55496 (det 0.45343 / str 0.10153)
# TwoHeadMetalCNN(
#   (trunk): Sequential(
#     (0): Conv1d(4, 64, kernel_size=(7,), stride=(1,), padding=(3,), padding_mode=replicate)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=replicate)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=replicate)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,), padding_mode=replicate)
#     (7): LeakyReLU(negative_slope=0.01)
#   )
#   (detect_head): Conv1d(64, 1, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=replicate)
#   (strength_head): Conv1d(64, 1, kernel_size=(3,), stride=(1,), padding=(1,), padding_mode=replicate)
# )

# %% [markdown]
# #### 8. Inference + turning predictions into a (rest wavelength, strength) catalog

# %%
def match_detections_v2(true_dets, pred_dets, tol_pix=3, tol_z=0.1):
    """
    Match detections using BOTH pixel proximity AND redshift proximity.
    
    This is more robust when CNN predictions shift peak locations, because
    we can match by physical redshift rather than just pixel index.
    
    Args:
        true_dets: list of true detection dicts
        pred_dets: list of predicted detection dicts
        tol_pix: pixel tolerance (backup if z matching fails)
        tol_z: redshift tolerance for matching (more robust)
        
    Returns:
        matched: list of (true_det, pred_det) tuples
        missed: list of unmatched true detections (false negatives)
        false_pos: list of unmatched predicted detections (false positives)
    """
    matched = []
    used_pred = set()
    
    for td in true_dets:
        best_pd = None
        best_dist = None
        best_idx = None
        
        for j, pd in enumerate(pred_dets):
            # Only match same metal species
            if pd["metal_name"] != td["metal_name"]:
                continue
            # Skip already-used predictions
            if j in used_pred:
                continue
            
            # Match by REDSHIFT PROXIMITY (more physical)
            z_dist = abs(pd["z_absorber"] - td["z_absorber"])
            
            # Match by PIXEL PROXIMITY (backup)
            pix_dist = abs(pd["pixel"] - td["pixel"])
            
            # Accept match if within either tolerance
            # Prefer z-distance match if both are satisfied
            if z_dist <= tol_z or pix_dist <= tol_pix:
                if best_dist is None or z_dist < best_dist:
                    best_pd = pd
                    best_dist = z_dist
                    best_idx = j
        
        # If match found, record it
        if best_pd is not None:
            matched.append((td, best_pd))
            used_pred.add(best_idx)
    
    # Collect unmatched detections
    missed = [td for td in true_dets if not any(td is m[0] for m in matched)]
    false_pos = [pd for j, pd in enumerate(pred_dets) if j not in used_pred]
    
    return matched, missed, false_pos

def extract_lines_v4(pred_maps, z_qso, rest_grid, metal_lines,
                                min_peak_tau=0.01, distance=3):
    """    
    Key insight: Absorbers at z_abs < z_qso appear BLUE-WARD of the metal
    rest wavelength in the REST frame (because we divide by 1+z_qso).
    """
    from scipy.signal import find_peaks
    
    detections = []
    
    for metal_name, metal_rest_wave in metal_lines.items():
        metal_idx = list(metal_lines.keys()).index(metal_name)
        if metal_idx >= len(pred_maps):
            continue
            
        tau = pred_maps[metal_idx]
        
        if tau.max() < min_peak_tau:
            continue
        
        # Find the pixel corresponding to the metal rest wavelength
        metal_pix = np.argmin(np.abs(rest_grid - metal_rest_wave))
        
        print(f"\n{metal_name}:")
        print(f"  Metal rest wave: {metal_rest_wave:.2f} Å")
        print(f"  Metal pixel: {metal_pix}")
        print(f"  REST_GRID[{metal_pix}]: {rest_grid[metal_pix]:.2f} Å")
        
        # ============ FIXED: Signal region is BLUE-WARD of metal line ============
        # Absorbers at z_abs < z_qso appear at shorter wavelengths (blue-ward)
        # So we look from the start of the grid up to and including the metal pixel
        signal_start = 0  # or some reasonable minimum
        signal_end = metal_pix + 1  # Include metal pixel and everything blue-ward
        signal_region = slice(signal_start, signal_end)
        
        print(f"  Signal region: pixels {signal_start} to {signal_end}")
        
        signal_tau = tau[signal_region]
        if len(signal_tau) == 0:
            continue
            
        print(f"  Signal tau range: [{signal_tau.min():.6f}, {signal_tau.max():.6f}]")
        
        # Compute noise in signal region
        median_tau = np.median(signal_tau)
        mad = np.median(np.abs(signal_tau - median_tau))
        noise = max(mad * 1.4826, 1e-4)
        
        print(f"  Noise level: {noise:.6f}")
        
        # Find peaks
        peaks, props = find_peaks(
            tau,
            height=3 * noise,
            prominence=2 * noise,
            distance=distance,
        )
        
        print(f"  Raw peaks found: {len(peaks)}")
        if len(peaks) > 0:
            print(f"    Pixels: {peaks}")
            print(f"    Tau values: {tau[peaks]}")
        
        dwave_rest = np.gradient(rest_grid).mean()
        
        for p_idx, p in enumerate(peaks):
            rest_wave_at_p = rest_grid[p]
            
            # ============ FIXED: Correct redshift calculation ============
            # If peak is at rest_wave_at_p in our frame (QSO rest frame),
            # and the metal has rest wavelength metal_rest_wave,
            # then the absorber is at:
            z_abs = (rest_wave_at_p * (1 + z_qso) / metal_rest_wave) - 1.0
            
            # ============ FIXED: Correct sanity checks ============
            # Peak must be in signal region (blue-ward of metal pixel)
            if p > metal_pix:
                print(f"    Reject peak at pix {p}: too red-ward of metal line")
                continue
            
            # Reasonable redshift (0 < z_abs < z_qso)
            if z_abs < 0 or z_abs > z_qso:
                print(f"    Reject peak at pix {p}: z_abs={z_abs:.3f} outside [0, {z_qso:.3f}]")
                continue
            
            peak_tau = tau[p]
            half_max = peak_tau / 2.0
            
            # Find FWHM
            left_edge = p
            for j in range(p - 1, -1, -1):
                if tau[j] < half_max:
                    left_edge = j
                    break
            
            right_edge = p
            for j in range(p + 1, len(tau)):
                if tau[j] < half_max:
                    right_edge = j
                    break
            
            measured_width_pixels = right_edge - left_edge
            measured_width_angstrom = measured_width_pixels * dwave_rest
            measured_width_kms = (measured_width_angstrom / metal_rest_wave) * 3e5
            
            # Integrate tau
            lo = max(0, p - 3)
            hi = min(len(rest_grid), p + 4)
            strength_int = np.trapz(tau[lo:hi], rest_grid[lo:hi])
            
            snr = peak_tau / noise if noise > 0 else float('inf')
            
            detection = {
                "metal_name": metal_name,
                "pixel": int(p),
                "rest_wavelength_A": metal_rest_wave,
                "z_absorber": z_abs,
                "peak_tau": float(peak_tau),
                "integrated_tau": float(strength_int),
                "measured_width_pixels": float(measured_width_pixels),
                "measured_width_angstrom": float(measured_width_angstrom),
                "measured_width_kms": float(measured_width_kms),
                "snr": float(snr),
                "prominence": float(props['prominences'][p_idx]) if len(props['prominences']) > p_idx else 0.0,
                "noise_level": float(noise),
            }
            
            detections.append(detection)
            print(f"    ✓ Accepted: pix {p}, z_abs={z_abs:.3f}, τ={peak_tau:.4f}")
    
    return detections

# %%
def extract_lines_two_head(detect_logits, strength_pred, z_qso, rest_grid, metal_lines,
                            prob_threshold=0.5, distance=3):
    """
    Replaces extract_lines_v4's local-MAD adaptive threshold with a fixed,
    calibrated probability cut on the detection head. Much less prone to
    reporting ripples in a flat background as detections, because the
    detection head was explicitly trained to push background probability
    toward 0 (via focal BCE) rather than being judged relative to its own
    output's local noise level.

    detect_logits, strength_pred: (N_METALS, N_PIX) numpy arrays (already
    squeezed out of the batch dimension).
    """
    from scipy.signal import find_peaks

    probs = 1.0 / (1.0 + np.exp(-detect_logits))  # sigmoid
    detections = []

    for metal_name, metal_rest_wave in metal_lines.items():
        idx = list(metal_lines.keys()).index(metal_name)
        if idx >= len(probs):
            continue

        p = probs[idx]
        strength = strength_pred[idx]

        peaks, props = find_peaks(p, height=prob_threshold, distance=distance)

        metal_pix = np.argmin(np.abs(rest_grid - metal_rest_wave))

        for pk in peaks:
            rest_wave_at_p = rest_grid[pk]
            z_abs = (rest_wave_at_p * (1 + z_qso) / metal_rest_wave) - 1.0

            # keep the same physical sanity checks as extract_lines_v4
            if pk > metal_pix:
                continue
            if z_abs < 0 or z_abs > z_qso:
                continue

            detections.append({
                "metal_name": metal_name,
                "pixel": int(pk),
                "rest_wavelength_A": metal_rest_wave,
                "z_absorber": z_abs,
                "detect_prob": float(p[pk]),
                "peak_tau": float(strength[pk]),
                "integrated_tau": float(np.trapz(
                    strength[max(0, pk - 3):min(len(strength), pk + 4)],
                    rest_grid[max(0, pk - 3):min(len(rest_grid), pk + 4)],
                )),
            })

    return detections


def predict_two_head(model, sample, device="cpu"):
    flux = sample["flux"].astype(np.float32)
    ivar = sample["ivar"].astype(np.float32) / 1e7
    shifted = make_shifted_channels(flux).astype(np.float32)
    lya_mask = make_lya_binary_channel(REST_GRID)
    # z_abs = make_absorber_z_channel(z_qso, REST_GRID, METAL_LINES["MgI(2853)"])
    # lya_structure = make_lya_structure_channel(flux)
    x = np.concatenate([flux[None, :], ivar[None, :], 
                        shifted, lya_mask[None,:], 
                        # z_abs[None,:],
                        # lya_structure[None,:]
                       ], 
                       axis=0)
    x_t = torch.from_numpy(x).unsqueeze(0).to(device)

    model.eval()
    with torch.no_grad():
        detect_logits, strength_pred = model(x_t)

    return detect_logits[0].cpu().numpy(), strength_pred[0].cpu().numpy()


# quick check on one validation sample
_sample = val_samples[1]
_detect_logits, _strength_pred = predict_two_head(model, _sample, device=device)

_true_dets = extract_lines_v4(_sample["label"], _sample["z_qso"], REST_GRID, METAL_LINES)
_pred_dets = extract_lines_two_head(_detect_logits, _strength_pred, _sample["z_qso"], REST_GRID, METAL_LINES)
_matched, _missed, _false_pos = match_detections_v2(_true_dets, _pred_dets, tol_pix=3)

print(f"true: {len(_true_dets)}  pred: {len(_pred_dets)}  "
      f"matched: {len(_matched)}  missed: {len(_missed)}  FP: {len(_false_pos)}")
# Out:
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.009856]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 190 195 198 201 207 211]
#     Tau values: [0.22499412 0.7916189  1.0098555  0.13202254 0.5950036  0.14295116
#  0.6416726 ]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.2250
#     ✓ Accepted: pix 190, z_abs=2.057, τ=0.7916
#     ✓ Accepted: pix 195, z_abs=2.131, τ=1.0099
#     ✓ Accepted: pix 198, z_abs=2.175, τ=0.1320
#     ✓ Accepted: pix 201, z_abs=2.221, τ=0.5950
#     ✓ Accepted: pix 207, z_abs=2.314, τ=0.1430
#     ✓ Accepted: pix 211, z_abs=2.377, τ=0.6417
# true: 7  pred: 8  matched: 7  missed: 0  FP: 1
# /tmp/ipykernel_2127558/177742671.py:16: RuntimeWarning: overflow encountered in exp
#   probs = 1.0 / (1.0 + np.exp(-detect_logits))  # sigmoid

# %% [markdown]
# ### 11.1 Check the data
#
# Two things to confirm before trusting anything downstream:
# 1. Whether noise is shared between the contaminated/uncontaminated files
#    (determines whether `build_paired_sample` alone is good enough, or
#    whether you need `build_averaged_pair_grids`).
# 2. That an injected SiII(1304) line is actually visible by eye in a
#    differenced pair, so you know what the model is being asked to learn.
#
# %%
# check a handful of targets, not just one -- the noise-sharing behavior
# should be consistent across targets, but it's cheap to confirm.

# %%
common_index = 0

# %%
example_tid = common_ids[common_index]
example_sample = build_paired_sample(
    example_tid, uncontaminated_path, contaminated_path,
    spectra_uncontam=spectra_uncontam, spectra_contam=spectra_contam,
)
if example_sample is None:
    raise RuntimeError(
        f"TARGETID {example_tid} has no forest coverage in the fixed rest-frame "
        "window -- pick a different target from common_ids to sanity-check."
    )
 
z_qso_ex = example_sample["z_qso"]
obs_wave_ex = REST_GRID * (1 + z_qso_ex)
label_sigma = np.zeros(N_PIX)
w = example_sample["weight"][0]
label_sigma[w > 0] = 1.0 / np.sqrt(w[w > 0])
 
fig, (axf, axt) = plt.subplots(
    2, 1, figsize=(12, 5), dpi=120, sharex=True,
    gridspec_kw={"height_ratios": [3, 1.5]},
)
axf.plot(obs_wave_ex, example_sample["flux"], color="tab:gray", alpha=0.8, label="contaminated flux")
axf.axhline(1.0, color="k", ls=":", alpha=0.4)
# axf.axvline(1304.37 * (1 + z_qso_ex), color="tab:red", ls="--", alpha=0.5, label="expected SiII(1304)")
axf.axvline(2852.96 * (1 + z_qso_ex), color="tab:red", ls="--", alpha=0.5, label="expected MgI(2853)")
axf.set_ylabel("Normalized flux")
axf.set_title(f"TARGETID = {example_tid}, z_qso = {z_qso_ex:.3f}")
axf.legend(loc="upper left")
 
axt.plot(obs_wave_ex, example_sample["label"][0], color="k", label="tau (diff)")
axt.fill_between(obs_wave_ex, -label_sigma, label_sigma, color="tab:gray", alpha=0.3, label="1-sigma label noise")
axt.axhline(0, color="r", ls="--", alpha=0.4)
# axf.axvline(1304.37 * (1 + z_qso_ex), color="tab:red", ls="--", alpha=0.5, label="expected SiII(1304)")
axf.axvline(2852.96 * (1 + z_qso_ex), color="tab:red", ls="--", alpha=0.5, label="expected MgI(2853)")
axt.set_ylabel("label tau")
axt.set_xlabel("Observed wavelength [A]")
axt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %%
stack_num = np.zeros(N_PIX)
stack_den = np.zeros(N_PIX)
n_stacked = 0
for tid in common_ids[:200]:
    s = build_paired_sample(
        tid, uncontaminated_path, contaminated_path,
        spectra_uncontam=spectra_uncontam, spectra_contam=spectra_contam,
    )
    if s is None:
        continue
    w = s["weight"][0]
    stack_num += s["label"][0] * w
    stack_den += w
    n_stacked += 1
 
stacked_label = np.divide(stack_num, stack_den, out=np.zeros(N_PIX), where=stack_den > 0)
stacked_sigma = np.zeros(N_PIX)
stacked_sigma[stack_den > 0] = 1.0 / np.sqrt(stack_den[stack_den > 0])
 
plt.figure(figsize=(9, 3.5), dpi=120)
plt.plot(REST_GRID, stacked_label, color="k", label=f"stacked tau (n={n_stacked})")
plt.fill_between(REST_GRID, -stacked_sigma, stacked_sigma, color="tab:gray", alpha=0.3)
# plt.axvline(1304.37, color="tab:red", ls="--", alpha=0.5, label="SiII(1304) rest wavelength")
plt.axvline(2852.96, color="tab:red", ls="--", alpha=0.5, label="MgI(2853) rest wavelength")
plt.axhline(0, color="r", ls=":", alpha=0.4)
plt.xlabel("Quasar rest-frame wavelength [A]")
plt.ylabel("stacked tau")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11.3 Check the output
#
# First a couple of individual spectra with the full plot (predicted vs.
# true tau, detected line markers), then aggregate completeness/purity and
# strength-recovery stats across the *entire* validation set so you're not
# judging performance off one or two cherry-picked examples.

# %%
all_matched, all_missed, all_fp = [], [], []
for s in val_samples:
    detect_logits, strength_pred = predict_two_head(model, s, device=device)
    true_dets = extract_lines_v4(s["label"], s["z_qso"], REST_GRID, METAL_LINES)
    pred_dets = extract_lines_two_head(detect_logits, strength_pred, s["z_qso"], REST_GRID, METAL_LINES)
    matched, missed, false_pos = match_detections_v2(true_dets, pred_dets, tol_pix=3)
    all_matched += matched
    all_missed += missed
    all_fp += false_pos

n_true = len(all_matched) + len(all_missed)
n_pred = len(all_matched) + len(all_fp)
completeness = len(all_matched) / n_true if n_true else float("nan")
purity = len(all_matched) / n_pred if n_pred else float("nan")

print(f"validation set: {len(val_samples)} spectra")
print(f"true lines:     {n_true}")
print(f"predicted:      {n_pred}")
print(f"completeness:   {completeness:.2f}")
print(f"purity:         {purity:.2f}")

if all_matched:
    true_s = np.array([m[0]["integrated_tau"] for m in all_matched])
    pred_s = np.array([m[1]["integrated_tau"] for m in all_matched])
    print(f"strength bias:    {np.mean(pred_s - true_s):.4f}")
    print(f"strength scatter: {np.std(pred_s - true_s):.4f}")

    plt.figure(figsize=(4, 4), dpi=110)
    lims = [0, max(true_s.max(), pred_s.max()) * 1.1 + 1e-6]
    plt.plot(lims, lims, "k--", alpha=0.5)
    plt.scatter(true_s, pred_s, s=15, alpha=0.7)
    plt.xlabel("true integrated tau")
    plt.ylabel("predicted integrated tau")
    plt.title("Two-head model: strength recovery")
    plt.tight_layout()
    plt.show()
# Out:
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.761757]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [187 190 196 199 203 206 209 212]
#     Tau values: [0.46520478 0.3939615  0.76175696 0.03724122 0.10076988 0.03123941
#  0.26827705 0.26967525]
#     ✓ Accepted: pix 187, z_abs=2.015, τ=0.4652
#     ✓ Accepted: pix 190, z_abs=2.058, τ=0.3940
#     ✓ Accepted: pix 196, z_abs=2.147, τ=0.7618
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.0372
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.1008
#     ✓ Accepted: pix 206, z_abs=2.299, τ=0.0312
#     ✓ Accepted: pix 209, z_abs=2.347, τ=0.2683
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.2697
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.009856]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 190 195 198 201 207 211]
#     Tau values: [0.22499412 0.7916189  1.0098555  0.13202254 0.5950036  0.14295116
#  0.6416726 ]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.2250
#     ✓ Accepted: pix 190, z_abs=2.057, τ=0.7916
#     ✓ Accepted: pix 195, z_abs=2.131, τ=1.0099
#     ✓ Accepted: pix 198, z_abs=2.175, τ=0.1320
#     ✓ Accepted: pix 201, z_abs=2.221, τ=0.5950
#     ✓ Accepted: pix 207, z_abs=2.314, τ=0.1430
#     ✓ Accepted: pix 211, z_abs=2.377, τ=0.6417
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.981665]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 191 195 199 203 207 210]
#     Tau values: [0.08666504 0.05129827 0.12204942 0.98166543 0.6892354  0.04743358
#  0.12890348]
#     ✓ Accepted: pix 186, z_abs=2.001, τ=0.0867
#     ✓ Accepted: pix 191, z_abs=2.073, τ=0.0513
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.1220
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.9817
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.6892
#     ✓ Accepted: pix 207, z_abs=2.315, τ=0.0474
#     ✓ Accepted: pix 210, z_abs=2.363, τ=0.1289
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.049010]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 189 195 198 203 208 212]
#     Tau values: [0.7573569  0.45114046 1.04901    0.22940615 1.0169755  0.06898599
#  0.4238983 ]
#     ✓ Accepted: pix 184, z_abs=1.969, τ=0.7574
#     ✓ Accepted: pix 189, z_abs=2.040, τ=0.4511
#     ✓ Accepted: pix 195, z_abs=2.128, τ=1.0490
#     ✓ Accepted: pix 198, z_abs=2.173, τ=0.2294
#     ✓ Accepted: pix 203, z_abs=2.249, τ=1.0170
#     ✓ Accepted: pix 208, z_abs=2.327, τ=0.0690
#     ✓ Accepted: pix 212, z_abs=2.390, τ=0.4239
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.100236]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 189 192 197 203 206 210]
#     Tau values: [0.6814609  0.11181192 0.04363329 0.4463946  0.04157909 1.0503827
#  1.1002359 ]
#     ✓ Accepted: pix 184, z_abs=1.972, τ=0.6815
#     ✓ Accepted: pix 189, z_abs=2.043, τ=0.1118
#     ✓ Accepted: pix 192, z_abs=2.087, τ=0.0436
#     ✓ Accepted: pix 197, z_abs=2.161, τ=0.4464
#     ✓ Accepted: pix 203, z_abs=2.252, τ=0.0416
#     ✓ Accepted: pix 206, z_abs=2.299, τ=1.0504
#     ✓ Accepted: pix 210, z_abs=2.362, τ=1.1002
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.832538]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [172 176 180 185 188 193 197 201]
#     Tau values: [0.08794133 0.5968038  0.7401352  0.13175485 0.7136307  0.57198673
#  0.44721398 0.83253825]
#     ✓ Accepted: pix 172, z_abs=1.971, τ=0.0879
#     ✓ Accepted: pix 176, z_abs=2.028, τ=0.5968
#     ✓ Accepted: pix 180, z_abs=2.086, τ=0.7401
#     ✓ Accepted: pix 185, z_abs=2.160, τ=0.1318
#     ✓ Accepted: pix 188, z_abs=2.205, τ=0.7136
#     ✓ Accepted: pix 193, z_abs=2.282, τ=0.5720
#     ✓ Accepted: pix 197, z_abs=2.345, τ=0.4472
#     ✓ Accepted: pix 201, z_abs=2.409, τ=0.8325
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.189807]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [131 134 138 141 144 148 154 158]
#     Tau values: [1.0699168  0.22950163 0.994982   1.1898073  1.146385   0.34466526
#  0.4257131  1.0530602 ]
#     ✓ Accepted: pix 131, z_abs=1.991, τ=1.0699
#     ✓ Accepted: pix 134, z_abs=2.033, τ=0.2295
#     ✓ Accepted: pix 138, z_abs=2.091, τ=0.9950
#     ✓ Accepted: pix 141, z_abs=2.136, τ=1.1898
#     ✓ Accepted: pix 144, z_abs=2.181, τ=1.1464
#     ✓ Accepted: pix 148, z_abs=2.242, τ=0.3447
#     ✓ Accepted: pix 154, z_abs=2.335, τ=0.4257
#     ✓ Accepted: pix 158, z_abs=2.399, τ=1.0531
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.547368]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [172 176 180 186 192 197 202]
#     Tau values: [0.05328169 0.12494934 0.41461855 0.07607985 0.27952263 0.54736805
#  0.01314444]
#     ✓ Accepted: pix 172, z_abs=1.976, τ=0.0533
#     ✓ Accepted: pix 176, z_abs=2.033, τ=0.1249
#     ✓ Accepted: pix 180, z_abs=2.091, τ=0.4146
#     ✓ Accepted: pix 186, z_abs=2.180, τ=0.0761
#     ✓ Accepted: pix 192, z_abs=2.272, τ=0.2795
#     ✓ Accepted: pix 197, z_abs=2.350, τ=0.5474
#     ✓ Accepted: pix 202, z_abs=2.431, τ=0.0131
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.981643]
#   Noise level: 0.000100
#   Raw peaks found: 9
#     Pixels: [160 163 168 172 175 180 184 187 190]
#     Tau values: [0.06782293 0.30385035 0.61424935 0.9269165  0.38639268 0.9816435
#  0.11379244 0.39611843 0.34530663]
#     ✓ Accepted: pix 160, z_abs=1.964, τ=0.0678
#     ✓ Accepted: pix 163, z_abs=2.006, τ=0.3039
#     ✓ Accepted: pix 168, z_abs=2.078, τ=0.6142
#     ✓ Accepted: pix 172, z_abs=2.137, τ=0.9269
#     ✓ Accepted: pix 175, z_abs=2.182, τ=0.3864
#     ✓ Accepted: pix 180, z_abs=2.258, τ=0.9816
#     ✓ Accepted: pix 184, z_abs=2.321, τ=0.1138
#     ✓ Accepted: pix 187, z_abs=2.368, τ=0.3961
#     ✓ Accepted: pix 190, z_abs=2.417, τ=0.3453
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.030222]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [151 154 159 162 167 172 179]
#     Tau values: [1.0302223  0.29069254 0.91919684 0.09279798 0.9148738  0.76121575
#  0.8790885 ]
#     ✓ Accepted: pix 151, z_abs=1.990, τ=1.0302
#     ✓ Accepted: pix 154, z_abs=2.033, τ=0.2907
#     ✓ Accepted: pix 159, z_abs=2.105, τ=0.9192
#     ✓ Accepted: pix 162, z_abs=2.150, τ=0.0928
#     ✓ Accepted: pix 167, z_abs=2.226, τ=0.9149
#     ✓ Accepted: pix 172, z_abs=2.303, τ=0.7612
#     ✓ Accepted: pix 179, z_abs=2.414, τ=0.8791
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.852428]
#   Noise level: 0.000100
#   Raw peaks found: 9
#     Pixels: [161 164 168 171 175 179 183 188 191]
#     Tau values: [0.57001615 0.7908654  0.2738565  0.20858975 0.26690227 0.74806744
#  0.01311235 0.85242814 0.05155762]
#     ✓ Accepted: pix 161, z_abs=1.980, τ=0.5700
#     ✓ Accepted: pix 164, z_abs=2.022, τ=0.7909
#     ✓ Accepted: pix 168, z_abs=2.080, τ=0.2739
#     ✓ Accepted: pix 171, z_abs=2.124, τ=0.2086
#     ✓ Accepted: pix 175, z_abs=2.184, τ=0.2669
#     ✓ Accepted: pix 179, z_abs=2.245, τ=0.7481
#     ✓ Accepted: pix 183, z_abs=2.307, τ=0.0131
#     ✓ Accepted: pix 188, z_abs=2.387, τ=0.8524
#     ✓ Accepted: pix 191, z_abs=2.435, τ=0.0516
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.106386]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [151 155 158 162 165 169 175 179]
#     Tau values: [0.2652918  0.2725233  0.24946047 1.1063856  0.8139561  0.18070064
#  0.7777753  0.8690594 ]
#     ✓ Accepted: pix 151, z_abs=1.987, τ=0.2653
#     ✓ Accepted: pix 155, z_abs=2.045, τ=0.2725
#     ✓ Accepted: pix 158, z_abs=2.088, τ=0.2495
#     ✓ Accepted: pix 162, z_abs=2.147, τ=1.1064
#     ✓ Accepted: pix 165, z_abs=2.192, τ=0.8140
#     ✓ Accepted: pix 169, z_abs=2.254, τ=0.1807
#     ✓ Accepted: pix 175, z_abs=2.347, τ=0.7778
#     ✓ Accepted: pix 179, z_abs=2.411, τ=0.8691
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.941506]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 190 193 197 203 209 212]
#     Tau values: [0.9415063  0.846166   0.30490574 0.44944626 0.42201    0.05974384
#  0.06466127]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.9415
#     ✓ Accepted: pix 190, z_abs=2.058, τ=0.8462
#     ✓ Accepted: pix 193, z_abs=2.102, τ=0.3049
#     ✓ Accepted: pix 197, z_abs=2.161, τ=0.4494
#     ✓ Accepted: pix 203, z_abs=2.252, τ=0.4220
#     ✓ Accepted: pix 209, z_abs=2.346, τ=0.0597
#     ✓ Accepted: pix 212, z_abs=2.394, τ=0.0647
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.891878]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [186 191 196 199 206 210]
#     Tau values: [0.20140076 0.48296392 0.68103206 0.26446518 0.47188908 0.8918779 ]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.2014
#     ✓ Accepted: pix 191, z_abs=2.072, τ=0.4830
#     ✓ Accepted: pix 196, z_abs=2.145, τ=0.6810
#     ✓ Accepted: pix 199, z_abs=2.191, τ=0.2645
#     ✓ Accepted: pix 206, z_abs=2.298, τ=0.4719
#     ✓ Accepted: pix 210, z_abs=2.361, τ=0.8919
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.906094]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [196 199 205 212]
#     Tau values: [0.00551966 0.01282954 0.9060939  0.10543999]
#     ✓ Accepted: pix 196, z_abs=1.962, τ=0.0055
#     ✓ Accepted: pix 199, z_abs=2.004, τ=0.0128
#     ✓ Accepted: pix 205, z_abs=2.091, τ=0.9061
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.1054
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.015980]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [174 178 183 187 191 194 198 201]
#     Tau values: [0.9017123  1.0159799  0.83217573 0.07148433 0.34949806 0.24759625
#  0.28734982 0.7025897 ]
#     ✓ Accepted: pix 174, z_abs=2.001, τ=0.9017
#     ✓ Accepted: pix 178, z_abs=2.058, τ=1.0160
#     ✓ Accepted: pix 183, z_abs=2.132, τ=0.8322
#     ✓ Accepted: pix 187, z_abs=2.192, τ=0.0715
#     ✓ Accepted: pix 191, z_abs=2.253, τ=0.3495
#     ✓ Accepted: pix 194, z_abs=2.299, τ=0.2476
#     ✓ Accepted: pix 198, z_abs=2.363, τ=0.2873
#     ✓ Accepted: pix 201, z_abs=2.411, τ=0.7026
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.172610]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [112 115 120 125 128 132 138]
#     Tau values: [1.1726098 1.01003   0.956837  0.5380532 1.1264565 0.9347336 1.0688711]
#     ✓ Accepted: pix 112, z_abs=1.980, τ=1.1726
#     ✓ Accepted: pix 115, z_abs=2.023, τ=1.0100
#     ✓ Accepted: pix 120, z_abs=2.096, τ=0.9568
#     ✓ Accepted: pix 125, z_abs=2.170, τ=0.5381
#     ✓ Accepted: pix 128, z_abs=2.215, τ=1.1265
#     ✓ Accepted: pix 132, z_abs=2.277, τ=0.9347
#     ✓ Accepted: pix 138, z_abs=2.371, τ=1.0689
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.204032]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [199 205 208 212]
#     Tau values: [0.13314694 0.0317045  0.20403191 0.04828208]
#     ✓ Accepted: pix 199, z_abs=2.004, τ=0.1331
#     ✓ Accepted: pix 205, z_abs=2.090, τ=0.0317
#     ✓ Accepted: pix 208, z_abs=2.135, τ=0.2040
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.0483
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.008644]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [174 178 182 187 191 194 200]
#     Tau values: [0.7661572  0.8401256  0.41503304 0.9723757  0.34104446 0.7803275
#  1.0086443 ]
#     ✓ Accepted: pix 174, z_abs=2.001, τ=0.7662
#     ✓ Accepted: pix 178, z_abs=2.059, τ=0.8401
#     ✓ Accepted: pix 182, z_abs=2.117, τ=0.4150
#     ✓ Accepted: pix 187, z_abs=2.192, τ=0.9724
#     ✓ Accepted: pix 191, z_abs=2.253, τ=0.3410
#     ✓ Accepted: pix 194, z_abs=2.300, τ=0.7803
#     ✓ Accepted: pix 200, z_abs=2.395, τ=1.0086
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.029842]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [150 155 159 162 166 170 173 179]
#     Tau values: [0.11531192 0.6125723  0.8335776  0.6886166  0.34966934 0.35268712
#  1.0298425  0.50952727]
#     ✓ Accepted: pix 150, z_abs=1.974, τ=0.1153
#     ✓ Accepted: pix 155, z_abs=2.046, τ=0.6126
#     ✓ Accepted: pix 159, z_abs=2.104, τ=0.8336
#     ✓ Accepted: pix 162, z_abs=2.148, τ=0.6886
#     ✓ Accepted: pix 166, z_abs=2.209, τ=0.3497
#     ✓ Accepted: pix 170, z_abs=2.270, τ=0.3527
#     ✓ Accepted: pix 173, z_abs=2.317, τ=1.0298
#     ✓ Accepted: pix 179, z_abs=2.413, τ=0.5095
# validation set: 20 spectra
# true lines:     143
# predicted:      204
# completeness:   0.94
# purity:         0.66
# strength bias:    0.1457
# strength scatter: 6.6214
# /tmp/ipykernel_2127558/177742671.py:16: RuntimeWarning: overflow encountered in exp
#   probs = 1.0 / (1.0 + np.exp(-detect_logits))  # sigmoid

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    _sample["flux"],
    label="flux",
)

shifted = make_shifted_channels(_sample["flux"])

for i in range(shifted.shape[0]):
    plt.plot(
        shifted[i],
        label=f"shifted {i}",
        alpha=0.7,
    )

# plt.xlim(0, 50)
plt.legend()
plt.show()

# %%
detect_logits, strength_pred = predict_two_head(
    model, val_samples[1], device=device
)

probs = torch.sigmoid(
    torch.from_numpy(detect_logits)
).numpy()

print("Logit stats:")
print("  min:", detect_logits.min())
print("  max:", detect_logits.max())
print("  mean:", detect_logits.mean())

print("\nProbability stats:")
print("  min:", probs.min())
print("  max:", probs.max())
print("  mean:", probs.mean())

for threshold in [0.01, 0.05, 0.1, 0.2, 0.3, 0.5]:
    print(f"pixels > {threshold}: {(probs > threshold).sum()}")
# Out:
# Logit stats:
#   min: -122.274765
#   max: 3.6671393
#   mean: -17.97393
#
# Probability stats:
#   min: 0.0
#   max: 0.9750871
#   mean: 0.08698358
# pixels > 0.01: 56
# pixels > 0.05: 38
# pixels > 0.1: 37
# pixels > 0.2: 35
# pixels > 0.3: 33
# pixels > 0.5: 21

# %%
# plt.figure(figsize=(12, 4))

# plt.plot(
#     probs[0],
#     label="detection probability",
# )

# plt.axhline(0.5, ls="--")

# # plt.xlim(0, 50)
# # plt.ylim(0, 1)

# plt.legend()
# plt.show()

# %%
all_peak_pixels = []

for s in train_samples:
    labels = s["label"]

    for metal in range(labels.shape[0]):
        peaks, _ = find_peaks(
            labels[metal],
            height=0.01,
            distance=3,
        )
        all_peak_pixels.extend(peaks)

plt.figure(figsize=(8, 4))
plt.hist(all_peak_pixels, bins=np.arange(257) - 0.5)
plt.xlabel("Peak pixel")
plt.ylabel("Number of true lines")
plt.title("Distribution of true metal-line locations in training set")
plt.show()

# %%
tp_pix = np.array([
    m[1]["pixel"] for m in all_matched
])

fp_pix = np.array([
    d["pixel"] for d in all_fp
])

miss_pix = np.array([
    d["pixel"] for d in all_missed
])

plt.figure(figsize=(9, 4))

bins = np.arange(-0.5, 256.5, 5)

plt.hist(tp_pix, bins=bins, histtype="step", linewidth=2, label="true positives")
plt.hist(fp_pix, bins=bins, histtype="step", linewidth=2, label="false positives")
plt.hist(miss_pix, bins=bins, histtype="step", linewidth=2, label="missed")

plt.xlabel("Pixel")
plt.ylabel("Number of detections")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# true_pix = []

# for s in val_samples:
#     for m in range(s["label"].shape[0]):
#         peaks, _ = find_peaks(
#             s["label"][m],
#             height=0.01,
#             distance=3
#         )
#         true_pix.extend(peaks)

# plt.figure(figsize=(9, 4))

# plt.hist(true_pix, bins=bins, histtype="step", linewidth=2, label="all true lines")
# plt.hist(fp_pix, bins=bins, histtype="step", linewidth=2, label="false positives")

# plt.xlabel("Pixel")
# plt.ylabel("Count")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
label_sigma = np.zeros(N_PIX)
w = example_sample["weight"][0]
label_sigma[w > 0] = 1.0 / np.sqrt(w[w > 0])

detect_logits, strength_pred = predict_two_head(
    model,
    example_sample,
    device=device,
)

prob = 1 / (1 + np.exp(-detect_logits[0]))

fig, ax1 = plt.subplots(figsize=(12, 4), dpi=120)

ax1.plot(
    obs_wave_ex,
    prob,
    label="CNN detection probability",
)
ax1.axhline(0.5, color="k", ls="--", alpha=0.5)
ax1.set_ylabel("Detection probability")
ax1.set_ylim(0, 1)

ax2 = ax1.twinx()

ax2.plot(
    obs_wave_ex,
    label_sigma,
    alpha=0.5,
    label="label noise σ",
)
ax2.set_ylabel("Label uncertainty")

ax1.axvline(
    2852.96 * (1 + z_qso_ex),
    ls="--",
    alpha=0.5,
)

ax1.set_xlabel("Observed wavelength [Å]")

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(
    lines1 + lines2,
    labels1 + labels2,
)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2127558/1834665550.py:11: RuntimeWarning: overflow encountered in exp
#   prob = 1 / (1 + np.exp(-detect_logits[0]))

# %%
def plot_prediction_vs_truth_verbose(
    model,
    sample,
    device="cpu",
    tol_pix=3,
    prob_threshold=0.5,
    distance=3,
):
    """
    Plot CNN prediction vs truth for the two-head metal-line detector.

    Top panel:
        Contaminated input flux with matched, missed, and false-positive
        detections marked.

    Bottom panel:
        True metal optical depth and CNN-predicted metal strength.

    Detection:
        Uses the two-head detection probability rather than treating the
        strength prediction itself as the detection criterion.

    Parameters
    ----------
    model : TwoHeadMetalCNN
        Trained two-head model.

    sample : dict
        Sample containing at least:
            "flux", "ivar", "z_qso", "label", "targetid"

    device : torch.device or str
        Device on which the model is located.

    tol_pix : int
        Pixel tolerance used for matching predicted and true detections.

    prob_threshold : float
        Detection-probability threshold passed to extract_lines_two_head.

    distance : int
        Minimum pixel separation between detected peaks.
    """

    model.eval()

    # ------------------------------------------------------------------
    # 1. Prepare input
    # ------------------------------------------------------------------

    flux = sample["flux"].astype(np.float32)
    ivar = sample["ivar"].astype(np.float32)

    # Normalize inverse variance exactly as during training
    IVAR_SCALE = 1e7
    ivar = ivar / IVAR_SCALE

    # Existing metal-shifted channels
    shifted = make_shifted_channels(flux).astype(np.float32)

    z_qso = sample["z_qso"]
    true_label = sample["label"]

    obs_wave = REST_GRID * (1.0 + z_qso)

    # Binary Lyα forest channel
    lya_mask = make_lya_binary_channel(REST_GRID)
    # z_abs = make_absorber_z_channel(z_qso, REST_GRID, METAL_LINES['MgI(2853)'])

    # lya_structure = make_lya_structure_channel(flux)
    
    # Input:
    #   channel 0       = flux
    #   channel 1       = ivar
    #   channels 2...   = shifted metal channels
    #   final channel   = Lyα mask
    
    x = np.concatenate([flux[None, :], ivar[None, :], 
                        shifted, lya_mask[None,:], 
                        # z_abs[None,:],
                        # lya_structure[None,:]
                       ], 
                       axis=0)
    

    x_t = torch.from_numpy(x).unsqueeze(0).to(device)

    # ------------------------------------------------------------------
    # 2. CNN prediction
    # ------------------------------------------------------------------

    with torch.no_grad():
        detect_logits, strength_pred = model(x_t)

    detect_logits = detect_logits[0].cpu().numpy()
    strength_pred = strength_pred[0].cpu().numpy()

    # ------------------------------------------------------------------
    # 3. Observed wavelength
    # ------------------------------------------------------------------

    # z_qso = sample["z_qso"]
    # true_label = sample["label"]

    # obs_wave = REST_GRID * (1.0 + z_qso)

    # ------------------------------------------------------------------
    # 4. Extract truth and CNN detections
    # ------------------------------------------------------------------

    true_dets = extract_lines_v4(
        true_label,
        z_qso,
        REST_GRID,
        METAL_LINES,
        min_peak_tau=0.01,
        distance=distance,
    )

    pred_dets = extract_lines_two_head(
        detect_logits,
        strength_pred,
        z_qso,
        REST_GRID,
        METAL_LINES,
        prob_threshold=prob_threshold,
        distance=distance,
    )

    # Match detections
    matched, missed, false_pos = match_detections_v2(
        true_dets,
        pred_dets,
        tol_pix=tol_pix,
    )

    # ------------------------------------------------------------------
    # 5. Plot
    # ------------------------------------------------------------------

    fig, (ax1, ax2) = plt.subplots(
        2,
        1,
        figsize=(15, 8),
        dpi=120,
        sharex=True,
        gridspec_kw={"height_ratios": [3, 2]},
    )

    # ==============================================================
    # TOP PANEL: contaminated flux
    # ==============================================================

    ax1.plot(
        obs_wave,
        flux,
        color="tab:gray",
        alpha=0.8,
        linewidth=1.2,
        label="contaminated flux",
    )

    ax1.axhline(
        1.0,
        color="k",
        ls=":",
        alpha=0.4,
        linewidth=1,
    )

    ax1.set_ylabel("Normalized flux", fontsize=11)

    ax1.set_title(
        f"TARGETID = {sample['targetid']}   "
        f"$z_{{qso}}$ = {z_qso:.3f}\n"
        f"True: {len(true_dets)} | "
        f"Pred: {len(pred_dets)} | "
        f"Matched: {len(matched)} | "
        f"Missed: {len(missed)} | "
        f"FP: {len(false_pos)} | "
        f"Purity: "
        f"{len(matched)/len(pred_dets):.2f}"
        if pred_dets
        else "N/A",
        fontsize=12,
        weight="bold",
    )

    ax1.set_ylim([0.85, 1.05])
    ax1.grid(True, alpha=0.2)

    # ==============================================================
    # BOTTOM PANEL: true vs predicted strength
    # ==============================================================

    for i, name in enumerate(METAL_NAMES):

        ax2.plot(
            obs_wave,
            true_label[i],
            color="k",
            alpha=0.5,
            linewidth=1.5,
            label="true τ" if i == 0 else None,
        )

        ax2.plot(
            obs_wave,
            strength_pred[i],
            color="tab:red",
            alpha=0.7,
            linewidth=1.5,
            label="CNN strength" if i == 0 else None,
        )

    # ==============================================================
    # MATCHED DETECTIONS -- GREEN
    # ==============================================================

    for j, (td, pd) in enumerate(matched):

        obsw = REST_GRID[td["pixel"]] * (1 + z_qso)

        ax1.axvline(
            obsw,
            color="green",
            ls="-",
            alpha=0.75,
            linewidth=2.5,
            label="matched" if j == 0 else None,
        )

        ax2.axvline(
            obsw,
            color="green",
            ls="-",
            alpha=0.75,
            linewidth=2.5,
        )

        # True and predicted values
        tau_true = td["peak_tau"]
        tau_pred = pd["peak_tau"]
        prob = pd["detect_prob"]

        # Annotate predicted probability and strength
        ymax = max(true_label.max(), strength_pred.max(), 0.05)

        ax2.text(
            obsw,
            ymax * 0.92,
            f"{prob:.2f}\n"
            f"$\\tau$: {tau_true:.2f} → {tau_pred:.2f}",
            ha="center",
            va="top",
            fontsize=7,
            color="green",
            weight="bold",
            bbox=dict(
                boxstyle="round,pad=0.25",
                facecolor="white",
                alpha=0.75,
            ),
        )

    # ==============================================================
    # MISSED DETECTIONS -- ORANGE
    # ==============================================================

    for j, td in enumerate(missed):

        obsw = REST_GRID[td["pixel"]] * (1 + z_qso)

        ax1.axvline(
            obsw,
            color="orange",
            ls="--",
            alpha=0.8,
            linewidth=2,
            label="missed (FN)" if j == 0 else None,
        )

        ax2.axvline(
            obsw,
            color="orange",
            ls="--",
            alpha=0.8,
            linewidth=2,
        )

        tau_true = td["peak_tau"]

        ymax = max(true_label.max(), strength_pred.max(), 0.05)

        ax2.text(
            obsw,
            ymax * 0.92,
            f"MISS\n"
            f"$\\tau$ = {tau_true:.2f}",
            ha="center",
            va="top",
            fontsize=7,
            color="orange",
            weight="bold",
            bbox=dict(
                boxstyle="round,pad=0.25",
                facecolor="white",
                alpha=0.75,
            ),
        )

    # ==============================================================
    # FALSE POSITIVES -- RED
    # ==============================================================

    for j, pd in enumerate(false_pos):

        obsw = REST_GRID[pd["pixel"]] * (1 + z_qso)

        ax1.axvline(
            obsw,
            color="red",
            ls=":",
            alpha=0.8,
            linewidth=2,
            label="false positive" if j == 0 else None,
        )

        ax2.axvline(
            obsw,
            color="red",
            ls=":",
            alpha=0.8,
            linewidth=2,
        )

        prob = pd["detect_prob"]
        tau_pred = pd["peak_tau"]

        ymax = max(true_label.max(), strength_pred.max(), 0.05)

        ax2.text(
            obsw,
            ymax * 0.55,
            f"FP\n"
            f"$P$ = {prob:.2f}\n"
            f"$\\tau$ = {tau_pred:.2f}",
            ha="center",
            va="top",
            fontsize=7,
            color="red",
            weight="bold",
            bbox=dict(
                boxstyle="round,pad=0.25",
                facecolor="white",
                alpha=0.75,
            ),
        )

    # Detection threshold annotation
    ax2.legend(
        loc="upper right",
        fontsize=9,
    )

    ax2.set_xlabel(
        "Observed wavelength [Å]",
        fontsize=11,
    )

    ax2.set_ylabel(
        "Optical depth / strength",
        fontsize=11,
    )

    ymax = max(
        true_label.max(),
        strength_pred.max(),
        0.05,
    )

    ax2.set_ylim(
        min(-0.05, strength_pred.min() * 1.1),
        ymax * 1.3,
    )

    ax2.grid(True, alpha=0.2)

    # --------------------------------------------------------------
    # Show Lyα forest region
    # --------------------------------------------------------------

    lya_obs_min = LYA_MIN * (1 + z_qso)
    lya_obs_max = LYA_MAX * (1 + z_qso)

    ax1.axvspan(
        lya_obs_min,
        lya_obs_max,
        alpha=0.08,
        label="Lyα forest",
    )

    ax2.axvspan(
        lya_obs_min,
        lya_obs_max,
        alpha=0.08,
    )

    # Rebuild top legend so the Lyα region is included
    ax1.legend(
        loc="lower right",
        fontsize=9,
    )

    plt.tight_layout()
    plt.show()

    # ==============================================================
    # 6. Print detection statistics
    # ==============================================================

    print("\n" + "=" * 60)
    print(
        f"TARGETID {sample['targetid']} | "
        f"z_qso = {z_qso:.3f}"
    )
    print("=" * 60)

    print(f"True detections:  {len(true_dets)}")
    print(f"Pred detections:  {len(pred_dets)}")
    print(f"Matched:          {len(matched)}")
    print(f"Missed (FN):      {len(missed)}")
    print(f"False positives:  {len(false_pos)}")

    if pred_dets:
        print(
            f"Purity:           "
            f"{len(matched) / len(pred_dets):.3f}"
        )

    if true_dets:
        print(
            f"Completeness:     "
            f"{len(matched) / len(true_dets):.3f}"
        )

    # ==============================================================
    # 7. Matched detections
    # ==============================================================

    if matched:

        print("\n--- MATCHED DETECTIONS ---")

        for td, pd in matched:

            print(
                f"  {td['metal_name']:15s}: "
                f"z={td['z_absorber']:.3f} | "
                f"τ_true={td['peak_tau']:.4f} → "
                f"τ_pred={pd['peak_tau']:.4f} | "
                f"P={pd['detect_prob']:.3f} | "
                f"pix_offset="
                f"{pd['pixel'] - td['pixel']:+d}"
            )

        true_strength = np.array(
            [m[0]["integrated_tau"] for m in matched]
        )

        pred_strength = np.array(
            [m[1]["integrated_tau"] for m in matched]
        )

        bias = np.mean(
            pred_strength - true_strength
        )

        scatter = np.std(
            pred_strength - true_strength
        )

        rmse = np.sqrt(
            np.mean(
                (pred_strength - true_strength) ** 2
            )
        )

        print("\nStrength recovery:")
        print(f"  bias:    {bias:+.4f}")
        print(f"  scatter: {scatter:.4f}")
        print(f"  RMSE:    {rmse:.4f}")

    # ==============================================================
    # 8. Missed detections
    # ==============================================================

    if missed:

        print("\n--- MISSED DETECTIONS ---")

        for td in missed:

            print(
                f"  {td['metal_name']:15s}: "
                f"z={td['z_absorber']:.3f} | "
                f"τ={td['peak_tau']:.4f} | "
                f"pix={td['pixel']}"
            )

    # ==============================================================
    # 9. False positives
    # ==============================================================

    if false_pos:

        print("\n--- FALSE POSITIVES ---")

        for pd in false_pos:

            print(
                f"  {pd['metal_name']:15s}: "
                f"z={pd['z_absorber']:.3f} | "
                f"P={pd['detect_prob']:.3f} | "
                f"τ_pred={pd['peak_tau']:.4f} | "
                f"pix={pd['pixel']}"
            )

    print("=" * 60 + "\n")

    return {
        "matched": matched,
        "missed": missed,
        "false_pos": false_pos,
        "true_dets": true_dets,
        "pred_dets": pred_dets,
        "detect_logits": detect_logits,
        "strength_pred": strength_pred,
    }

# %%
plot_prediction_vs_truth_verbose(
    model,
    # sample,
    val_samples[0],
    device="cpu",
    tol_pix=3,
    prob_threshold=0.5,
    distance=3,
)
# Out:
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.761757]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [187 190 196 199 203 206 209 212]
#     Tau values: [0.46520478 0.3939615  0.76175696 0.03724122 0.10076988 0.03123941
#  0.26827705 0.26967525]
#     ✓ Accepted: pix 187, z_abs=2.015, τ=0.4652
#     ✓ Accepted: pix 190, z_abs=2.058, τ=0.3940
#     ✓ Accepted: pix 196, z_abs=2.147, τ=0.7618
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.0372
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.1008
#     ✓ Accepted: pix 206, z_abs=2.299, τ=0.0312
#     ✓ Accepted: pix 209, z_abs=2.347, τ=0.2683
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.2697
# /tmp/ipykernel_2127558/177742671.py:16: RuntimeWarning: overflow encountered in exp
#   probs = 1.0 / (1.0 + np.exp(-detect_logits))  # sigmoid
# ============================================================
# TARGETID 1070 | z_qso = 2.401
# ============================================================
# True detections:  8
# Pred detections:  9
# Matched:          7
# Missed (FN):      1
# False positives:  2
# Purity:           0.778
# Completeness:     0.875
#
# --- MATCHED DETECTIONS ---
#   MgI(2853)      : z=2.015 | τ_true=0.4652 → τ_pred=0.5190 | P=0.851 | pix_offset=+0
#   MgI(2853)      : z=2.058 | τ_true=0.3940 → τ_pred=0.3825 | P=0.878 | pix_offset=+0
#   MgI(2853)      : z=2.147 | τ_true=0.7618 → τ_pred=0.7535 | P=0.950 | pix_offset=+0
#   MgI(2853)      : z=2.192 | τ_true=0.0372 → τ_pred=0.0697 | P=0.689 | pix_offset=+0
#   MgI(2853)      : z=2.253 | τ_true=0.1008 → τ_pred=0.1281 | P=0.552 | pix_offset=+3
#   MgI(2853)      : z=2.299 | τ_true=0.0312 → τ_pred=0.1894 | P=0.782 | pix_offset=+3
#   MgI(2853)      : z=2.347 | τ_true=0.2683 → τ_pred=0.3279 | P=0.865 | pix_offset=+3
#
# Strength recovery:
#   bias:    +0.4917
#   scatter: 1.3800
#   RMSE:    1.4649
#
# --- MISSED DETECTIONS ---
#   MgI(2853)      : z=2.395 | τ=0.2697 | pix=212
#
# --- FALSE POSITIVES ---
#   MgI(2853)      : z=1.945 | P=0.671 | τ_pred=0.0853 | pix=182
#   MgI(2853)      : z=2.102 | P=0.648 | τ_pred=-0.0896 | pix=193
# ============================================================
# {'matched': [({'metal_name': 'MgI(2853)',
#     'pixel': 187,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.0152612837679267,
#     'peak_tau': 0.46520477533340454,
#     'integrated_tau': 14.788626109520294,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 4652.047753334045,
#     'prominence': 0.4625379752833396,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 187,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.0152612837679267,
#     'detect_prob': 0.8513480424880981,
#     'peak_tau': 0.5189664363861084,
#     'integrated_tau': 16.21195925927764}),
#   ({'metal_name': 'MgI(2853)',
#     'pixel': 190,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.05844826992113,
#     'peak_tau': 0.39396148920059204,
#     'integrated_tau': 9.869272915279286,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 3939.6148920059204,
#     'prominence': 0.39065437763929367,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 190,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.05844826992113,
#     'detect_prob': 0.8778975605964661,
#     'peak_tau': 0.3825276494026184,
#     'integrated_tau': 10.044847896075472}),
#   ({'metal_name': 'MgI(2853)',
#     'pixel': 196,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.14668677749372,
#     'peak_tau': 0.761756956577301,
#     'integrated_tau': 12.195603677557802,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 7617.56956577301,
#     'prominence': 0.761756956577301,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 196,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.14668677749372,
#     'detect_prob': 0.9501944184303284,
#     'peak_tau': 0.7534778118133545,
#     'integrated_tau': 10.838169037334913}),
#   ({'metal_name': 'MgI(2853)',
#     'pixel': 199,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.1917561447885765,
#     'peak_tau': 0.03724122419953346,
#     'integrated_tau': 6.652841669100275,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 372.4122419953346,
#     'prominence': 0.0354710603132844,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 199,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.1917561447885765,
#     'detect_prob': 0.6892601251602173,
#     'peak_tau': 0.06966225802898407,
#     'integrated_tau': 6.52728826056937}),
#   ({'metal_name': 'MgI(2853)',
#     'pixel': 203,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.252854370271604,
#     'peak_tau': 0.10076988488435745,
#     'integrated_tau': 2.122055089148068,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 1007.6988488435745,
#     'prominence': 0.09985457448055968,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 206,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.2994443548290184,
#     'detect_prob': 0.5518907308578491,
#     'peak_tau': 0.12810096144676208,
#     'integrated_tau': 1.700441533955436}),
#   ({'metal_name': 'MgI(2853)',
#     'pixel': 206,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.2994443548290184,
#     'peak_tau': 0.03123941458761692,
#     'integrated_tau': 3.3769753276037404,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 312.3941458761692,
#     'prominence': 0.027558221016079187,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 209,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.346701638445652,
#     'detect_prob': 0.7824110984802246,
#     'peak_tau': 0.18943563103675842,
#     'integrated_tau': 6.648550721544204}),
#   ({'metal_name': 'MgI(2853)',
#     'pixel': 209,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.346701638445652,
#     'peak_tau': 0.26827704906463623,
#     'integrated_tau': 6.90385842549286,
#     'measured_width_pixels': 2.0,
#     'measured_width_angstrom': 19.218588991592625,
#     'measured_width_kms': 2020.910457026312,
#     'snr': 2682.7704906463623,
#     'prominence': 0.2678154348686803,
#     'noise_level': 0.0001},
#    {'metal_name': 'MgI(2853)',
#     'pixel': 212,
#     'rest_wavelength_A': 2852.96,
#     'z_absorber': 2.3946357787128734,
#     'detect_prob': 0.8647584915161133,
#     'peak_tau': 0.32793980836868286,
#     'integrated_tau': 7.379592414070593})],
#  'missed': [{'metal_name': 'MgI(2853)',
#    'pixel': 212,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.3946357787128734,
#    'peak_tau': 0.26967525482177734,
#    'integrated_tau': 6.384851089572912,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 2696.7525482177734,
#    'prominence': 0.26951075505348854,
#    'noise_level': 0.0001}],
#  'false_pos': [{'metal_name': 'MgI(2853)',
#    'pixel': 182,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 1.9446338810079493,
#    'detect_prob': 0.6711735725402832,
#    'peak_tau': 0.08531773090362549,
#    'integrated_tau': 8.157985167809066},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 193,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.102253814665938,
#    'detect_prob': 0.6478368043899536,
#    'peak_tau': -0.08958613872528076,
#    'integrated_tau': 9.502884768438062}],
#  'true_dets': [{'metal_name': 'MgI(2853)',
#    'pixel': 187,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.0152612837679267,
#    'peak_tau': 0.46520477533340454,
#    'integrated_tau': 14.788626109520294,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 4652.047753334045,
#    'prominence': 0.4625379752833396,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 190,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.05844826992113,
#    'peak_tau': 0.39396148920059204,
#    'integrated_tau': 9.869272915279286,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 3939.6148920059204,
#    'prominence': 0.39065437763929367,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 196,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.14668677749372,
#    'peak_tau': 0.761756956577301,
#    'integrated_tau': 12.195603677557802,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 7617.56956577301,
#    'prominence': 0.761756956577301,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 199,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.1917561447885765,
#    'peak_tau': 0.03724122419953346,
#    'integrated_tau': 6.652841669100275,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 372.4122419953346,
#    'prominence': 0.0354710603132844,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 203,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.252854370271604,
#    'peak_tau': 0.10076988488435745,
#    'integrated_tau': 2.122055089148068,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 1007.6988488435745,
#    'prominence': 0.09985457448055968,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 206,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.2994443548290184,
#    'peak_tau': 0.03123941458761692,
#    'integrated_tau': 3.3769753276037404,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 312.3941458761692,
#    'prominence': 0.027558221016079187,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 209,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.346701638445652,
#    'peak_tau': 0.26827704906463623,
#    'integrated_tau': 6.90385842549286,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 2682.7704906463623,
#    'prominence': 0.2678154348686803,
#    'noise_level': 0.0001},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 212,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.3946357787128734,
#    'peak_tau': 0.26967525482177734,
#    'integrated_tau': 6.384851089572912,
#    'measured_width_pixels': 2.0,
#    'measured_width_angstrom': 19.218588991592625,
#    'measured_width_kms': 2020.910457026312,
#    'snr': 2696.7525482177734,
#    'prominence': 0.26951075505348854,
#    'noise_level': 0.0001}],
#  'pred_dets': [{'metal_name': 'MgI(2853)',
#    'pixel': 182,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 1.9446338810079493,
#    'detect_prob': 0.6711735725402832,
#    'peak_tau': 0.08531773090362549,
#    'integrated_tau': 8.157985167809066},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 187,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.0152612837679267,
#    'detect_prob': 0.8513480424880981,
#    'peak_tau': 0.5189664363861084,
#    'integrated_tau': 16.21195925927764},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 190,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.05844826992113,
#    'detect_prob': 0.8778975605964661,
#    'peak_tau': 0.3825276494026184,
#    'integrated_tau': 10.044847896075472},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 193,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.102253814665938,
#    'detect_prob': 0.6478368043899536,
#    'peak_tau': -0.08958613872528076,
#    'integrated_tau': 9.502884768438062},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 196,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.14668677749372,
#    'detect_prob': 0.9501944184303284,
#    'peak_tau': 0.7534778118133545,
#    'integrated_tau': 10.838169037334913},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 199,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.1917561447885765,
#    'detect_prob': 0.6892601251602173,
#    'peak_tau': 0.06966225802898407,
#    'integrated_tau': 6.52728826056937},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 206,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.2994443548290184,
#    'detect_prob': 0.5518907308578491,
#    'peak_tau': 0.12810096144676208,
#    'integrated_tau': 1.700441533955436},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 209,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.346701638445652,
#    'detect_prob': 0.7824110984802246,
#    'peak_tau': 0.18943563103675842,
#    'integrated_tau': 6.648550721544204},
#   {'metal_name': 'MgI(2853)',
#    'pixel': 212,
#    'rest_wavelength_A': 2852.96,
#    'z_absorber': 2.3946357787128734,
#    'detect_prob': 0.8647584915161133,
#    'peak_tau': 0.32793980836868286,
#    'integrated_tau': 7.379592414070593}],
#  'detect_logits': array([[-1.25106506e+02, -1.25125389e+02, -1.25097801e+02,
#          -1.24946144e+02, -1.24747887e+02, -1.23867477e+02,
#          -1.22852180e+02, -1.21381729e+02, -1.20031113e+02,
#          -1.18347649e+02, -1.16382195e+02, -1.15088303e+02,
#          -1.13651703e+02, -1.13009918e+02, -1.12401459e+02,
#          -1.12518661e+02, -1.12562820e+02, -1.13229622e+02,
#          -1.14088898e+02, -1.14665298e+02, -1.15372536e+02,
#          -1.16031471e+02, -1.16045265e+02, -1.15218933e+02,
#          -1.13307823e+02, -1.09611992e+02, -1.03594215e+02,
#          -9.58057556e+01, -8.57266846e+01, -7.38261108e+01,
#          -6.15161781e+01, -4.90908470e+01, -3.77991524e+01,
#          -2.83650551e+01, -1.97729130e+01, -1.34777412e+01,
#          -9.93471241e+00, -7.63331413e+00, -6.13722801e+00,
#          -5.41680145e+00, -5.08526993e+00, -4.87928486e+00,
#          -4.77479172e+00, -4.65251875e+00, -4.46949291e+00,
#          -4.68116426e+00, -5.09235382e+00, -5.27368259e+00,
#          -5.26652336e+00, -5.29558706e+00, -5.35104036e+00,
#          -5.56670475e+00, -5.78809357e+00, -5.76710892e+00,
#          -5.68241739e+00, -5.81016684e+00, -5.91210175e+00,
#          -6.06780052e+00, -6.38260078e+00, -6.54282999e+00,
#          -6.61473703e+00, -6.84833956e+00, -6.95368338e+00,
#          -6.74380827e+00, -6.61378527e+00, -6.64780807e+00,
#          -6.62064457e+00, -6.55298138e+00, -6.53837919e+00,
#          -6.56661224e+00, -6.61364222e+00, -6.67190647e+00,
#          -6.75049639e+00, -6.83129883e+00, -6.81844378e+00,
#          -6.75774050e+00, -6.69302225e+00, -6.63939428e+00,
#          -6.65507460e+00, -6.77410698e+00, -6.89672804e+00,
#          -6.87467194e+00, -7.16923428e+00, -8.10425854e+00,
#          -7.75216579e+00, -7.01158237e+00, -7.42708492e+00,
#          -7.64932919e+00, -7.45669985e+00, -7.35815334e+00,
#          -7.35729647e+00, -7.29198790e+00, -7.14093018e+00,
#          -7.03663206e+00, -7.08782768e+00, -7.19760704e+00,
#          -6.64429712e+00, -5.97230768e+00, -5.82058096e+00,
#          -5.49482059e+00, -4.97533607e+00, -4.70933151e+00,
#          -4.66909456e+00, -4.65043259e+00, -4.69336796e+00,
#          -4.93833303e+00, -5.17690611e+00, -5.40102911e+00,
#          -5.80712080e+00, -6.08325052e+00, -6.06647825e+00,
#          -6.15628290e+00, -6.30904913e+00, -6.34702206e+00,
#          -6.34876633e+00, -6.35355902e+00, -6.39343452e+00,
#          -6.44091558e+00, -6.37081337e+00, -6.23074150e+00,
#          -6.13263845e+00, -5.99202585e+00, -5.76020527e+00,
#          -5.44256496e+00, -5.13029051e+00, -4.77113008e+00,
#          -4.58597374e+00, -4.73821211e+00, -4.34261656e+00,
#          -4.24342585e+00, -4.39800215e+00, -4.41764116e+00,
#          -4.54782820e+00, -4.57622385e+00, -4.68871307e+00,
#          -4.75308943e+00, -4.76513100e+00, -4.80134439e+00,
#          -4.77130651e+00, -4.78017521e+00, -4.83303738e+00,
#          -4.83696318e+00, -4.88734627e+00, -4.93699026e+00,
#          -4.96711111e+00, -4.97070503e+00, -4.88565111e+00,
#          -4.78304386e+00, -4.65186787e+00, -4.52557850e+00,
#          -4.39045143e+00, -4.24980593e+00, -4.07144690e+00,
#          -3.88843727e+00, -3.72965980e+00, -3.45229483e+00,
#          -3.15046597e+00, -2.93267322e+00, -2.69724679e+00,
#          -2.52241373e+00, -2.28785801e+00, -2.02662158e+00,
#          -2.02152944e+00, -2.06652737e+00, -2.20525026e+00,
#          -2.48866081e+00, -3.00276303e+00, -3.55777121e+00,
#          -4.02420712e+00, -4.58818007e+00, -5.15566540e+00,
#          -5.52103090e+00, -5.70198441e+00, -5.66458797e+00,
#          -5.36073399e+00, -4.69120836e+00, -3.85364342e+00,
#          -2.79548836e+00, -1.38862097e+00, -4.03084159e-01,
#          -2.37299372e-02,  3.05532634e-01,  7.13497877e-01,
#           3.08530629e-01,  6.45633101e-01,  1.66353488e+00,
#          -2.53913403e-02,  1.74521363e+00,  7.36652166e-02,
#          -3.78126830e-01,  1.97266984e+00,  1.70336485e-01,
#           5.77122450e-01,  6.09544039e-01, -4.05623354e-02,
#           3.66813168e-02,  2.94853878e+00,  1.92128584e-01,
#          -8.08965981e-01,  7.96662629e-01,  5.24236798e-01,
#           2.54071709e-02, -2.43534222e-01, -9.77768674e-02,
#          -9.14995849e-01, -1.10521376e+00,  2.08313152e-01,
#          -2.44638473e-01, -3.17143828e-01,  1.27977252e+00,
#          -2.52971649e-01,  4.85484958e-01,  1.85538840e+00,
#          -1.39776260e-01, -5.81898019e-02,  3.39839458e-01,
#          -5.20866215e-01, -1.61939728e+00, -3.29419112e+00,
#          -4.48246384e+00, -5.30722332e+00, -5.86165762e+00,
#          -6.03180408e+00, -5.93376732e+00, -5.69366837e+00,
#          -5.48853302e+00, -5.39569902e+00, -5.37142229e+00,
#          -5.36268473e+00, -5.36930990e+00, -5.42530584e+00,
#          -5.57009697e+00, -5.74484396e+00, -5.85047483e+00,
#          -5.88439322e+00, -5.86423683e+00, -5.75094652e+00,
#          -5.62096739e+00, -5.49962759e+00, -5.29372978e+00,
#          -5.14072323e+00, -5.16362810e+00, -5.25334501e+00,
#          -5.33801460e+00, -5.50905943e+00, -5.72836828e+00,
#          -5.93177509e+00, -6.11783695e+00, -6.24619627e+00,
#          -6.32267523e+00, -6.36269188e+00, -6.36166191e+00,
#          -6.34668255e+00, -6.33469200e+00, -6.31319046e+00,
#          -6.29835558e+00]], dtype=float32),
#  'strength_pred': array([[-0.49675128, -0.46872213, -0.4753661 , -0.46298787, -0.5915132 ,
#          -0.46871555, -0.5431322 , -0.42971006, -0.60740733, -0.5771406 ,
#          -0.4632506 , -0.59907603, -0.37296858, -0.5896191 , -0.36271456,
#          -0.55234146, -0.28827542, -0.4687094 , -0.43295717, -0.38675213,
#          -0.3870016 , -0.44211236, -0.41957483, -0.43249804, -0.49572283,
#          -0.50925577, -0.48292473, -0.66337466, -0.64163554, -0.54823035,
#          -0.58702344, -0.43486336, -0.4801186 , -0.65076685, -0.2785875 ,
#          -0.06085604, -0.05423446, -0.08994729, -0.07333219, -0.06175558,
#          -0.05756248, -0.07112514, -0.09144261, -0.06014758,  0.03150161,
#           0.0124523 , -0.07763515, -0.10726899, -0.06747103, -0.02028723,
#           0.02396847, -0.01676111, -0.08588348, -0.07752681, -0.04045628,
#          -0.05210728, -0.03165684, -0.02132328, -0.05315425, -0.02916386,
#          -0.00494687, -0.05234094, -0.08745735, -0.03590772, -0.01704848,
#          -0.03917497, -0.05383189, -0.049756  , -0.05036232, -0.04903371,
#          -0.04597592, -0.03709897, -0.0298597 , -0.04004842, -0.03991554,
#          -0.0415163 , -0.04519436, -0.05526812, -0.0520382 , -0.04065325,
#          -0.00398362,  0.07595452,  0.09557459, -0.26157755, -0.06924762,
#           0.11010302,  0.03386223, -0.05452796, -0.04651985, -0.04521231,
#          -0.05824199, -0.05565976, -0.01676744,  0.01329187, -0.02160276,
#          -0.15217558, -0.04425803,  0.0229045 , -0.03049539, -0.07194669,
#          -0.04908537, -0.0453246 , -0.06958672, -0.07131273, -0.04166123,
#          -0.042001  , -0.01893718,  0.00115346, -0.0502358 , -0.08026386,
#          -0.02761531, -0.02664283, -0.045739  , -0.04507961, -0.039503  ,
#          -0.03006253, -0.04170155, -0.06047513, -0.04612733, -0.02428781,
#          -0.03449683, -0.05070335, -0.05656277, -0.04975023, -0.03419636,
#          -0.00119943, -0.00480463, -0.12893212, -0.01828461, -0.03123128,
#          -0.0385872 , -0.03774044, -0.04924951, -0.02768284, -0.04712022,
#          -0.03035006, -0.02805681, -0.04351121, -0.0335495 , -0.0356808 ,
#          -0.04875517, -0.04726685, -0.04827574, -0.03419305, -0.03940592,
#          -0.04355867, -0.02810009, -0.03633096, -0.04119851, -0.04576364,
#          -0.04467552, -0.05357736, -0.0429365 , -0.02671604, -0.03971538,
#          -0.03967346, -0.0236433 , -0.0259103 , -0.03371032, -0.06097802,
#          -0.04817007, -0.00276467, -0.01143072, -0.0132593 , -0.0174882 ,
#           0.00268661, -0.02347365, -0.05070055, -0.02027924, -0.00358017,
#          -0.02277821, -0.02913795, -0.0189123 , -0.02221826, -0.04278407,
#          -0.02307737, -0.04584007, -0.07275941, -0.02438887, -0.00533669,
#           0.0154351 ,  0.08043607,  0.08531773,  0.14276876,  0.1091118 ,
#           0.5238092 ,  0.03902971,  0.51896644,  0.03790683, -0.0101338 ,
#           0.38252765, -0.02441325,  0.2271344 , -0.08958614,  0.13140988,
#          -0.0438794 ,  0.7534778 ,  0.03951321, -0.00451944,  0.06966226,
#           0.00592255,  0.03846985, -0.01413239,  0.11843883, -0.04385925,
#          -0.05553311,  0.12810096,  0.01492369, -0.06850167,  0.18943563,
#          -0.02353713,  0.15644148,  0.3279398 , -0.03177557,  0.02687387,
#          -0.00492144,  0.01956568,  0.06316583, -0.03140307, -0.02670459,
#          -0.01460797, -0.03625317, -0.06347585, -0.07754391, -0.05884312,
#          -0.04688027, -0.05715864, -0.07813827, -0.08386287, -0.06865802,
#          -0.04683212, -0.0476266 , -0.06232975, -0.06710616, -0.06375936,
#          -0.06131183, -0.0511528 , -0.05893191, -0.07720584, -0.06281811,
#          -0.04968275, -0.06393357, -0.07933377, -0.06494025, -0.05780595,
#          -0.05408683, -0.05282902, -0.05836885, -0.06076022, -0.06249848,
#          -0.06430639, -0.06239183, -0.06248676, -0.06555729, -0.0649076 ,
#          -0.06479207]], dtype=float32)}

# %%
def plot_strength_diagnostics(
    model,
    samples,
    device="cpu",
    prob_threshold=0.5,
    distance=3,
    tol_pix=3,
    max_samples=None,
):
    """
    Compare predicted vs. true metal-line strengths for matched detections.

    Produces:
        1. True vs predicted peak tau
        2. True vs predicted integrated tau
        3. Fractional / absolute residuals vs true strength
        4. Histograms of true and predicted strengths

    Only matched detections are included in the strength comparison.

    Parameters
    ----------
    model : TwoHeadMetalCNN
        Trained model.

    samples : list of dict
        Validation/test samples.

    device : torch.device or str
        Model device.

    prob_threshold : float
        Detection probability threshold.

    distance : int
        Minimum peak separation.

    tol_pix : int
        Pixel tolerance for matching detections.

    max_samples : int or None
        Optional limit on number of samples to process.
    """

    model.eval()

    if max_samples is not None:
        samples_to_use = samples[:max_samples]
    else:
        samples_to_use = samples

    all_matched = []

    # ------------------------------------------------------------
    # Run model and collect matched detections
    # ------------------------------------------------------------

    for sample in samples_to_use:

        flux = sample["flux"].astype(np.float32)
        ivar = sample["ivar"].astype(np.float32)

        IVAR_SCALE = 1e7
        ivar = ivar / IVAR_SCALE

        shifted = make_shifted_channels(flux).astype(np.float32)
        lya_mask = make_lya_binary_channel(REST_GRID)

        x = np.concatenate(
            [
                flux[None, :],
                ivar[None, :],
                shifted,
                lya_mask[None, :],
            ],
            axis=0,
        )

        x_t = torch.from_numpy(x).unsqueeze(0).to(device)

        with torch.no_grad():
            detect_logits, strength_pred = model(x_t)

        detect_logits = detect_logits[0].cpu().numpy()
        strength_pred = strength_pred[0].cpu().numpy()

        # Truth
        true_dets = extract_lines_v4(
            sample["label"],
            sample["z_qso"],
            REST_GRID,
            METAL_LINES,
            min_peak_tau=0.001,
            distance=distance,
        )

        # Prediction
        pred_dets = extract_lines_two_head(
            detect_logits,
            strength_pred,
            sample["z_qso"],
            REST_GRID,
            METAL_LINES,
            prob_threshold=prob_threshold,
            distance=distance,
        )

        matched, missed, false_pos = match_detections_v2(
            true_dets,
            pred_dets,
            tol_pix=tol_pix,
        )

        all_matched.extend(matched)

    # ------------------------------------------------------------
    # Check for matches
    # ------------------------------------------------------------

    if len(all_matched) == 0:
        print("No matched detections found.")
        return None

    # ------------------------------------------------------------
    # Extract strengths
    # ------------------------------------------------------------

    true_peak = np.array(
        [m[0]["peak_tau"] for m in all_matched]
    )

    pred_peak = np.array(
        [m[1]["peak_tau"] for m in all_matched]
    )

    true_integrated = np.array(
        [m[0]["integrated_tau"] for m in all_matched]
    )

    pred_integrated = np.array(
        [m[1]["integrated_tau"] for m in all_matched]
    )

    # Residuals
    peak_residual = pred_peak - true_peak
    integrated_residual = pred_integrated - true_integrated

    # Fractional residuals
    peak_frac = peak_residual / np.maximum(true_peak, 1e-6)
    integrated_frac = integrated_residual / np.maximum(
        true_integrated, 1e-6
    )

    # ------------------------------------------------------------
    # Statistics
    # ------------------------------------------------------------

    print("\n" + "=" * 60)
    print("STRENGTH RECOVERY DIAGNOSTICS")
    print("=" * 60)

    print(f"Matched detections: {len(all_matched)}")

    print("\nPeak tau:")
    print(f"  bias:    {np.mean(peak_residual):+.4f}")
    print(f"  scatter: {np.std(peak_residual):.4f}")
    print(
        f"  RMSE:    "
        f"{np.sqrt(np.mean(peak_residual**2)):.4f}"
    )

    print("\nIntegrated tau:")
    print(f"  bias:    {np.mean(integrated_residual):+.4f}")
    print(f"  scatter: {np.std(integrated_residual):.4f}")
    print(
        f"  RMSE:    "
        f"{np.sqrt(np.mean(integrated_residual**2)):.4f}"
    )

    print("\nMedian fractional residual:")
    print(f"  peak:       {np.median(peak_frac):+.3f}")
    print(f"  integrated: {np.median(integrated_frac):+.3f}")

    # ------------------------------------------------------------
    # Figure
    # ------------------------------------------------------------

    fig, axes = plt.subplots(
        2,
        2,
        figsize=(12, 10),
        dpi=120,
    )

    ax1, ax2, ax3, ax4 = axes.flatten()

    # ============================================================
    # 1. Peak tau: true vs predicted
    # ============================================================

    ax1.scatter(
        true_peak,
        pred_peak,
        s=35,
        alpha=0.65,
        edgecolors="k",
        linewidths=0.5,
    )

    peak_max = max(
        true_peak.max(),
        pred_peak.max(),
    )

    lims = [0, peak_max * 1.05]

    ax1.plot(
        lims,
        lims,
        "k--",
        alpha=0.6,
        label="1:1",
    )

    ax1.set_xlim(lims)
    ax1.set_ylim(lims)

    ax1.set_xlabel("True peak τ")
    ax1.set_ylabel("Predicted peak τ")

    ax1.set_title("Peak Optical Depth Recovery")
    ax1.legend(loc='upper right')

    ax1.text(
        0.05,
        0.95,
        f"Bias = {np.mean(peak_residual):+.3f}\n"
        f"Scatter = {np.std(peak_residual):.3f}",
        transform=ax1.transAxes,
        va="top",
        bbox=dict(
            boxstyle="round",
            facecolor="white",
            alpha=0.8,
        ),
    )

    # ============================================================
    # 2. Integrated tau: true vs predicted
    # ============================================================

    ax2.scatter(
        true_integrated,
        pred_integrated,
        s=35,
        alpha=0.65,
        edgecolors="k",
        linewidths=0.5,
    )

    int_max = max(
        true_integrated.max(),
        pred_integrated.max(),
    )

    lims = [0, int_max * 1.05]

    ax2.plot(
        lims,
        lims,
        "k--",
        alpha=0.6,
        label="1:1",
    )

    ax2.set_xlim(lims)
    ax2.set_ylim(lims)

    ax2.set_xlabel("True integrated τ")
    ax2.set_ylabel("Predicted integrated τ")

    ax2.set_title("Integrated Optical Depth Recovery")
    ax2.legend(loc='upper right')

    ax2.text(
        0.05,
        0.95,
        f"Bias = {np.mean(integrated_residual):+.3f}\n"
        f"Scatter = {np.std(integrated_residual):.3f}",
        transform=ax2.transAxes,
        va="top",
        bbox=dict(
            boxstyle="round",
            facecolor="white",
            alpha=0.8,
        ),
    )

    # ============================================================
    # 3. Peak residuals vs true strength
    # ============================================================

    ax3.axhline(
        0,
        color="k",
        ls="--",
        alpha=0.5,
    )

    ax3.scatter(
        true_peak,
        peak_residual,
        s=35,
        alpha=0.65,
        edgecolors="k",
        linewidths=0.5,
    )

    ax3.set_xlabel("True peak τ")
    ax3.set_ylabel("Predicted − true peak τ")

    ax3.set_title("Peak τ Residuals")

    ax3.grid(alpha=0.2)

    # ============================================================
    # 4. Strength distributions
    # ============================================================

    bins_peak = np.linspace(
        0,
        max(
            true_peak.max(),
            pred_peak.max(),
        ) * 1.05,
        20,
    )

    ax4.hist(
        true_peak,
        bins=bins_peak,
        alpha=0.55,
        label="True",
    )

    ax4.hist(
        pred_peak,
        bins=bins_peak,
        alpha=0.55,
        label="Predicted",
    )

    ax4.set_xlabel("Peak τ")
    ax4.set_ylabel("Count")

    ax4.set_title("Peak τ Distribution")

    ax4.legend()

    ax4.grid(
        axis="y",
        alpha=0.2,
    )

    fig.suptitle(
        "Metal-line Strength Recovery",
        fontsize=15,
        weight="bold",
    )

    plt.savefig('diagnostic_plot.png')

    plt.tight_layout()
    plt.show()

    return {
        "matched": all_matched,
        "true_peak": true_peak,
        "pred_peak": pred_peak,
        "true_integrated": true_integrated,
        "pred_integrated": pred_integrated,
        "peak_residual": peak_residual,
        "integrated_residual": integrated_residual,
        "peak_fractional_residual": peak_frac,
        "integrated_fractional_residual": integrated_frac,
    }

# %%
plot_strength_diagnostics(
    model,
    samples,
    device="cpu",
    prob_threshold=0.5,
    distance=3,
    tol_pix=3,
    max_samples=None,
)
# Out:
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.032160]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [197 201 205 211]
#     Tau values: [0.16593114 1.0072619  1.0321597  0.08784933]
#     ✓ Accepted: pix 197, z_abs=1.977, τ=0.1659
#     ✓ Accepted: pix 201, z_abs=2.034, τ=1.0073
#     ✓ Accepted: pix 205, z_abs=2.092, τ=1.0322
#     ✓ Accepted: pix 211, z_abs=2.181, τ=0.0878
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.204032]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [199 205 208 212]
#     Tau values: [0.13314694 0.0317045  0.20403191 0.04828208]
#     ✓ Accepted: pix 199, z_abs=2.004, τ=0.1331
#     ✓ Accepted: pix 205, z_abs=2.090, τ=0.0317
#     ✓ Accepted: pix 208, z_abs=2.135, τ=0.2040
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.0483
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.557967]
#   Noise level: 0.000100
#   Raw peaks found: 3
#     Pixels: [197 204 212]
#     Tau values: [0.1355073  0.55796736 0.24913263]
#     ✓ Accepted: pix 197, z_abs=1.976, τ=0.1355
#     ✓ Accepted: pix 204, z_abs=2.076, τ=0.5580
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.2491
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.810002]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [197 203 207 210]
#     Tau values: [0.43860772 0.5680893  0.8100019  0.6179985 ]
#     ✓ Accepted: pix 197, z_abs=1.976, τ=0.4386
#     ✓ Accepted: pix 203, z_abs=2.062, τ=0.5681
#     ✓ Accepted: pix 207, z_abs=2.120, τ=0.8100
#     ✓ Accepted: pix 210, z_abs=2.165, τ=0.6180
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.378216]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [198 202 208 211]
#     Tau values: [0.378216   0.24535511 0.03408079 0.33745584]
#     ✓ Accepted: pix 198, z_abs=1.990, τ=0.3782
#     ✓ Accepted: pix 202, z_abs=2.047, τ=0.2454
#     ✓ Accepted: pix 208, z_abs=2.135, τ=0.0341
#     ✓ Accepted: pix 211, z_abs=2.180, τ=0.3375
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.424515]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [198 202 207 211]
#     Tau values: [0.4245153  0.22997653 0.02260642 0.01961445]
#     ✓ Accepted: pix 198, z_abs=1.991, τ=0.4245
#     ✓ Accepted: pix 202, z_abs=2.048, τ=0.2300
#     ✓ Accepted: pix 207, z_abs=2.121, τ=0.0226
#     ✓ Accepted: pix 211, z_abs=2.181, τ=0.0196
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.503560]
#   Noise level: 0.000100
#   Raw peaks found: 5
#     Pixels: [196 201 204 208 212]
#     Tau values: [0.04208783 0.2420402  0.5035596  0.07237409 0.25650188]
#     ✓ Accepted: pix 196, z_abs=1.963, τ=0.0421
#     ✓ Accepted: pix 201, z_abs=2.034, τ=0.2420
#     ✓ Accepted: pix 204, z_abs=2.077, τ=0.5036
#     ✓ Accepted: pix 208, z_abs=2.136, τ=0.0724
#     ✓ Accepted: pix 212, z_abs=2.196, τ=0.2565
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.470229]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [197 202 207 211]
#     Tau values: [0.47022915 0.06943879 0.05780539 0.02143459]
#     ✓ Accepted: pix 197, z_abs=1.975, τ=0.4702
#     ✓ Accepted: pix 202, z_abs=2.046, τ=0.0694
#     ✓ Accepted: pix 207, z_abs=2.119, τ=0.0578
#     ✓ Accepted: pix 211, z_abs=2.179, τ=0.0214
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.581584]
#   Noise level: 0.000100
#   Raw peaks found: 5
#     Pixels: [196 199 202 207 211]
#     Tau values: [0.5815837  0.00475536 0.51505095 0.10063922 0.43300357]
#     ✓ Accepted: pix 196, z_abs=1.962, τ=0.5816
#     ✓ Accepted: pix 199, z_abs=2.004, τ=0.0048
#     ✓ Accepted: pix 202, z_abs=2.047, τ=0.5151
#     ✓ Accepted: pix 207, z_abs=2.120, τ=0.1006
#     ✓ Accepted: pix 211, z_abs=2.180, τ=0.4330
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.544656]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [198 201 206 212]
#     Tau values: [0.5446557  0.08832874 0.11817124 0.00580733]
#     ✓ Accepted: pix 198, z_abs=1.990, τ=0.5447
#     ✓ Accepted: pix 201, z_abs=2.032, τ=0.0883
#     ✓ Accepted: pix 206, z_abs=2.105, τ=0.1182
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.0058
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.129291]
#   Noise level: 0.000100
#   Raw peaks found: 3
#     Pixels: [197 203 209]
#     Tau values: [0.04061541 0.12929103 0.02450467]
#     ✓ Accepted: pix 197, z_abs=1.976, τ=0.0406
#     ✓ Accepted: pix 203, z_abs=2.062, τ=0.1293
#     ✓ Accepted: pix 209, z_abs=2.150, τ=0.0245
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.317129]
#   Noise level: 0.000100
#   Raw peaks found: 5
#     Pixels: [198 202 206 209 212]
#     Tau values: [0.29915556 0.07026722 0.317129   0.15523031 0.2970461 ]
#     ✓ Accepted: pix 198, z_abs=1.990, τ=0.2992
#     ✓ Accepted: pix 202, z_abs=2.047, τ=0.0703
#     ✓ Accepted: pix 206, z_abs=2.105, τ=0.3171
#     ✓ Accepted: pix 209, z_abs=2.150, τ=0.1552
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.2970
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.865897]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [197 202 207 212]
#     Tau values: [0.01351587 0.865897   0.03733931 0.03848256]
#     ✓ Accepted: pix 197, z_abs=1.975, τ=0.0135
#     ✓ Accepted: pix 202, z_abs=2.046, τ=0.8659
#     ✓ Accepted: pix 207, z_abs=2.119, τ=0.0373
#     ✓ Accepted: pix 212, z_abs=2.194, τ=0.0385
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.906094]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [196 199 205 212]
#     Tau values: [0.00551966 0.01282954 0.9060939  0.10543999]
#     ✓ Accepted: pix 196, z_abs=1.962, τ=0.0055
#     ✓ Accepted: pix 199, z_abs=2.004, τ=0.0128
#     ✓ Accepted: pix 205, z_abs=2.091, τ=0.9061
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.1054
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.805626]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [197 205 208 211]
#     Tau values: [0.21789494 0.6316952  0.8056259  0.04641131]
#     ✓ Accepted: pix 197, z_abs=1.977, τ=0.2179
#     ✓ Accepted: pix 205, z_abs=2.092, τ=0.6317
#     ✓ Accepted: pix 208, z_abs=2.136, τ=0.8056
#     ✓ Accepted: pix 211, z_abs=2.181, τ=0.0464
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.391255]
#   Noise level: 0.000100
#   Raw peaks found: 5
#     Pixels: [196 199 203 207 211]
#     Tau values: [0.05516566 0.01432013 0.10050716 0.19699723 0.3912552 ]
#     ✓ Accepted: pix 196, z_abs=1.963, τ=0.0552
#     ✓ Accepted: pix 199, z_abs=2.005, τ=0.0143
#     ✓ Accepted: pix 203, z_abs=2.063, τ=0.1005
#     ✓ Accepted: pix 207, z_abs=2.122, τ=0.1970
#     ✓ Accepted: pix 211, z_abs=2.181, τ=0.3913
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.508877]
#   Noise level: 0.000100
#   Raw peaks found: 5
#     Pixels: [197 200 203 206 211]
#     Tau values: [0.5088768  0.47409555 0.03408748 0.29557678 0.02090933]
#     ✓ Accepted: pix 197, z_abs=1.975, τ=0.5089
#     ✓ Accepted: pix 200, z_abs=2.018, τ=0.4741
#     ✓ Accepted: pix 203, z_abs=2.061, τ=0.0341
#     ✓ Accepted: pix 206, z_abs=2.105, τ=0.2956
#     ✓ Accepted: pix 211, z_abs=2.179, τ=0.0209
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.887054]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [196 201 208 211]
#     Tau values: [0.02413073 0.29847834 0.07173002 0.887054  ]
#     ✓ Accepted: pix 196, z_abs=1.961, τ=0.0241
#     ✓ Accepted: pix 201, z_abs=2.032, τ=0.2985
#     ✓ Accepted: pix 208, z_abs=2.135, τ=0.0717
#     ✓ Accepted: pix 211, z_abs=2.179, τ=0.8871
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.650430]
#   Noise level: 0.000100
#   Raw peaks found: 5
#     Pixels: [196 199 203 207 212]
#     Tau values: [0.00698525 0.15546155 0.18571092 0.65042967 0.02101909]
#     ✓ Accepted: pix 196, z_abs=1.961, τ=0.0070
#     ✓ Accepted: pix 199, z_abs=2.004, τ=0.1555
#     ✓ Accepted: pix 203, z_abs=2.061, τ=0.1857
#     ✓ Accepted: pix 207, z_abs=2.120, τ=0.6504
#     ✓ Accepted: pix 212, z_abs=2.195, τ=0.0210
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.637618]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [196 200 203 210]
#     Tau values: [0.00551982 0.2939694  0.6376176  0.33249518]
#     ✓ Accepted: pix 196, z_abs=1.961, τ=0.0055
#     ✓ Accepted: pix 200, z_abs=2.018, τ=0.2940
#     ✓ Accepted: pix 203, z_abs=2.061, τ=0.6376
#     ✓ Accepted: pix 210, z_abs=2.164, τ=0.3325
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.561847]
#   Noise level: 0.000100
#   Raw peaks found: 4
#     Pixels: [196 201 208 212]
#     Tau values: [0.3124453  0.47929156 0.56184745 0.2508552 ]
#     ✓ Accepted: pix 196, z_abs=1.963, τ=0.3124
#     ✓ Accepted: pix 201, z_abs=2.034, τ=0.4793
#     ✓ Accepted: pix 208, z_abs=2.136, τ=0.5618
#     ✓ Accepted: pix 212, z_abs=2.196, τ=0.2509
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.614122]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [188 191 195 200 206 210]
#     Tau values: [0.2673904  0.43695065 0.40606603 0.61412215 0.20771524 0.5845634 ]
#     ✓ Accepted: pix 188, z_abs=2.029, τ=0.2674
#     ✓ Accepted: pix 191, z_abs=2.072, τ=0.4370
#     ✓ Accepted: pix 195, z_abs=2.131, τ=0.4061
#     ✓ Accepted: pix 200, z_abs=2.206, τ=0.6141
#     ✓ Accepted: pix 206, z_abs=2.298, τ=0.2077
#     ✓ Accepted: pix 210, z_abs=2.362, τ=0.5846
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.968393]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [187 191 197 200 208 211]
#     Tau values: [0.50437784 0.12388671 0.08270752 0.9683932  0.10951018 0.703917  ]
#     ✓ Accepted: pix 187, z_abs=2.012, τ=0.5044
#     ✓ Accepted: pix 191, z_abs=2.069, τ=0.1239
#     ✓ Accepted: pix 197, z_abs=2.158, τ=0.0827
#     ✓ Accepted: pix 200, z_abs=2.203, τ=0.9684
#     ✓ Accepted: pix 208, z_abs=2.327, τ=0.1095
#     ✓ Accepted: pix 211, z_abs=2.374, τ=0.7039
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.928956]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [186 189 192 195 199 202 205 212]
#     Tau values: [0.6385049  0.9289564  0.00831625 0.57253796 0.6864835  0.06317313
#  0.9131231  0.20525678]
#     ✓ Accepted: pix 186, z_abs=2.001, τ=0.6385
#     ✓ Accepted: pix 189, z_abs=2.044, τ=0.9290
#     ✓ Accepted: pix 192, z_abs=2.088, τ=0.0083
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.5725
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.6865
#     ✓ Accepted: pix 202, z_abs=2.238, τ=0.0632
#     ✓ Accepted: pix 205, z_abs=2.284, τ=0.9131
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.2053
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.890614]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [188 192 195 198 206 212]
#     Tau values: [0.42006785 0.89061385 0.3308675  0.7692852  0.28081557 0.0485828 ]
#     ✓ Accepted: pix 188, z_abs=2.028, τ=0.4201
#     ✓ Accepted: pix 192, z_abs=2.086, τ=0.8906
#     ✓ Accepted: pix 195, z_abs=2.130, τ=0.3309
#     ✓ Accepted: pix 198, z_abs=2.175, τ=0.7693
#     ✓ Accepted: pix 206, z_abs=2.297, τ=0.2808
#     ✓ Accepted: pix 212, z_abs=2.393, τ=0.0486
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.978929]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [184 187 192 196 200 205 208 212]
#     Tau values: [0.06827875 0.5553047  0.69193554 0.03863342 0.97892886 0.4694237
#  0.00914912 0.14135516]
#     ✓ Accepted: pix 184, z_abs=1.974, τ=0.0683
#     ✓ Accepted: pix 187, z_abs=2.017, τ=0.5553
#     ✓ Accepted: pix 192, z_abs=2.089, τ=0.6919
#     ✓ Accepted: pix 196, z_abs=2.148, τ=0.0386
#     ✓ Accepted: pix 200, z_abs=2.208, τ=0.9789
#     ✓ Accepted: pix 205, z_abs=2.285, τ=0.4694
#     ✓ Accepted: pix 208, z_abs=2.332, τ=0.0091
#     ✓ Accepted: pix 212, z_abs=2.396, τ=0.1414
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.855532]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [185 189 192 198 201 207 210]
#     Tau values: [0.8555323  0.18656644 0.56045914 0.5793277  0.74968594 0.20057319
#  0.05520854]
#     ✓ Accepted: pix 185, z_abs=1.985, τ=0.8555
#     ✓ Accepted: pix 189, z_abs=2.042, τ=0.1866
#     ✓ Accepted: pix 192, z_abs=2.085, τ=0.5605
#     ✓ Accepted: pix 198, z_abs=2.174, τ=0.5793
#     ✓ Accepted: pix 201, z_abs=2.220, τ=0.7497
#     ✓ Accepted: pix 207, z_abs=2.313, τ=0.2006
#     ✓ Accepted: pix 210, z_abs=2.360, τ=0.0552
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.866487]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [186 195 200 205 208 211]
#     Tau values: [0.8664874  0.24773498 0.67249346 0.602853   0.6250337  0.02683161]
#     ✓ Accepted: pix 186, z_abs=2.001, τ=0.8665
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.2477
#     ✓ Accepted: pix 200, z_abs=2.207, τ=0.6725
#     ✓ Accepted: pix 205, z_abs=2.284, τ=0.6029
#     ✓ Accepted: pix 208, z_abs=2.331, τ=0.6250
#     ✓ Accepted: pix 211, z_abs=2.379, τ=0.0268
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.902612]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [185 190 196 200 203 206 211]
#     Tau values: [0.32359603 0.90261227 0.4950051  0.6984761  0.11859977 0.3864149
#  0.13743961]
#     ✓ Accepted: pix 185, z_abs=1.984, τ=0.3236
#     ✓ Accepted: pix 190, z_abs=2.055, τ=0.9026
#     ✓ Accepted: pix 196, z_abs=2.143, τ=0.4950
#     ✓ Accepted: pix 200, z_abs=2.203, τ=0.6985
#     ✓ Accepted: pix 203, z_abs=2.249, τ=0.1186
#     ✓ Accepted: pix 206, z_abs=2.296, τ=0.3864
#     ✓ Accepted: pix 211, z_abs=2.375, τ=0.1374
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.772058]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [185 190 196 200 205 210]
#     Tau values: [0.02600252 0.77205825 0.2883901  0.5225606  0.10402507 0.29135662]
#     ✓ Accepted: pix 185, z_abs=1.985, τ=0.0260
#     ✓ Accepted: pix 190, z_abs=2.057, τ=0.7721
#     ✓ Accepted: pix 196, z_abs=2.145, τ=0.2884
#     ✓ Accepted: pix 200, z_abs=2.205, τ=0.5226
#     ✓ Accepted: pix 205, z_abs=2.282, τ=0.1040
#     ✓ Accepted: pix 210, z_abs=2.361, τ=0.2914
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.650739]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 189 193 198 202 205 210]
#     Tau values: [0.38982138 0.03609053 0.32896644 0.00849648 0.11366431 0.6507388
#  0.10539027]
#     ✓ Accepted: pix 186, z_abs=1.998, τ=0.3898
#     ✓ Accepted: pix 189, z_abs=2.041, τ=0.0361
#     ✓ Accepted: pix 193, z_abs=2.099, τ=0.3290
#     ✓ Accepted: pix 198, z_abs=2.174, τ=0.0085
#     ✓ Accepted: pix 202, z_abs=2.234, τ=0.1137
#     ✓ Accepted: pix 205, z_abs=2.281, τ=0.6507
#     ✓ Accepted: pix 210, z_abs=2.359, τ=0.1054
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.947492]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [185 188 192 196 199 202 205 209]
#     Tau values: [0.8050336  0.03863887 0.00900232 0.18494332 0.9474919  0.4335026
#  0.02334318 0.28970307]
#     ✓ Accepted: pix 185, z_abs=1.988, τ=0.8050
#     ✓ Accepted: pix 188, z_abs=2.030, τ=0.0386
#     ✓ Accepted: pix 192, z_abs=2.088, τ=0.0090
#     ✓ Accepted: pix 196, z_abs=2.147, τ=0.1849
#     ✓ Accepted: pix 199, z_abs=2.193, τ=0.9475
#     ✓ Accepted: pix 202, z_abs=2.238, τ=0.4335
#     ✓ Accepted: pix 205, z_abs=2.285, τ=0.0233
#     ✓ Accepted: pix 209, z_abs=2.348, τ=0.2897
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.657557]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [184 187 192 195 199 202 205 209]
#     Tau values: [0.33014464 0.28212336 0.6575568  0.16214679 0.13210492 0.39174238
#  0.47766167 0.40216348]
#     ✓ Accepted: pix 184, z_abs=1.970, τ=0.3301
#     ✓ Accepted: pix 187, z_abs=2.012, τ=0.2821
#     ✓ Accepted: pix 192, z_abs=2.084, τ=0.6576
#     ✓ Accepted: pix 195, z_abs=2.129, τ=0.1621
#     ✓ Accepted: pix 199, z_abs=2.189, τ=0.1321
#     ✓ Accepted: pix 202, z_abs=2.234, τ=0.3917
#     ✓ Accepted: pix 205, z_abs=2.281, τ=0.4777
#     ✓ Accepted: pix 209, z_abs=2.343, τ=0.4022
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.789871]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [185 189 192 196 199 204 209 212]
#     Tau values: [0.01664699 0.40615276 0.3672793  0.05587612 0.23818055 0.78987134
#  0.16115493 0.17474347]
#     ✓ Accepted: pix 185, z_abs=1.987, τ=0.0166
#     ✓ Accepted: pix 189, z_abs=2.044, τ=0.4062
#     ✓ Accepted: pix 192, z_abs=2.088, τ=0.3673
#     ✓ Accepted: pix 196, z_abs=2.147, τ=0.0559
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.2382
#     ✓ Accepted: pix 204, z_abs=2.269, τ=0.7899
#     ✓ Accepted: pix 209, z_abs=2.347, τ=0.1612
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.1747
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.699637]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [185 189 192 196 201 205 209 212]
#     Tau values: [0.47264606 0.06067249 0.69963706 0.10819716 0.15535058 0.10205639
#  0.2005811  0.01650879]
#     ✓ Accepted: pix 185, z_abs=1.985, τ=0.4726
#     ✓ Accepted: pix 189, z_abs=2.042, τ=0.0607
#     ✓ Accepted: pix 192, z_abs=2.086, τ=0.6996
#     ✓ Accepted: pix 196, z_abs=2.145, τ=0.1082
#     ✓ Accepted: pix 201, z_abs=2.220, τ=0.1554
#     ✓ Accepted: pix 205, z_abs=2.282, τ=0.1021
#     ✓ Accepted: pix 209, z_abs=2.345, τ=0.2006
#     ✓ Accepted: pix 212, z_abs=2.392, τ=0.0165
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.485642]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 189 194 197 202 206 210]
#     Tau values: [0.17584261 0.35716707 0.07848976 0.19564107 0.05975114 0.00714743
#  0.4856423 ]
#     ✓ Accepted: pix 184, z_abs=1.967, τ=0.1758
#     ✓ Accepted: pix 189, z_abs=2.039, τ=0.3572
#     ✓ Accepted: pix 194, z_abs=2.111, τ=0.0785
#     ✓ Accepted: pix 197, z_abs=2.156, τ=0.1956
#     ✓ Accepted: pix 202, z_abs=2.232, τ=0.0598
#     ✓ Accepted: pix 206, z_abs=2.294, τ=0.0071
#     ✓ Accepted: pix 210, z_abs=2.357, τ=0.4856
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.731945]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [187 192 199 203 208 211]
#     Tau values: [0.14811411 0.4999412  0.73194516 0.38766944 0.58234334 0.6088049 ]
#     ✓ Accepted: pix 187, z_abs=2.015, τ=0.1481
#     ✓ Accepted: pix 192, z_abs=2.087, τ=0.4999
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.7319
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.3877
#     ✓ Accepted: pix 208, z_abs=2.331, τ=0.5823
#     ✓ Accepted: pix 211, z_abs=2.378, τ=0.6088
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.761757]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [187 190 196 199 203 206 209 212]
#     Tau values: [0.46520478 0.3939615  0.76175696 0.03724122 0.10076988 0.03123941
#  0.26827705 0.26967525]
#     ✓ Accepted: pix 187, z_abs=2.015, τ=0.4652
#     ✓ Accepted: pix 190, z_abs=2.058, τ=0.3940
#     ✓ Accepted: pix 196, z_abs=2.147, τ=0.7618
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.0372
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.1008
#     ✓ Accepted: pix 206, z_abs=2.299, τ=0.0312
#     ✓ Accepted: pix 209, z_abs=2.347, τ=0.2683
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.2697
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.882642]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [184 189 192 195 198 203 209 212]
#     Tau values: [0.5349578  0.42071396 0.39634272 0.19065888 0.73802084 0.88264227
#  0.6469235  0.37770543]
#     ✓ Accepted: pix 184, z_abs=1.975, τ=0.5350
#     ✓ Accepted: pix 189, z_abs=2.046, τ=0.4207
#     ✓ Accepted: pix 192, z_abs=2.090, τ=0.3963
#     ✓ Accepted: pix 195, z_abs=2.134, τ=0.1907
#     ✓ Accepted: pix 198, z_abs=2.179, τ=0.7380
#     ✓ Accepted: pix 203, z_abs=2.255, τ=0.8826
#     ✓ Accepted: pix 209, z_abs=2.349, τ=0.6469
#     ✓ Accepted: pix 212, z_abs=2.397, τ=0.3777
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.049010]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 189 195 198 203 208 212]
#     Tau values: [0.7573569  0.45114046 1.04901    0.22940615 1.0169755  0.06898599
#  0.4238983 ]
#     ✓ Accepted: pix 184, z_abs=1.969, τ=0.7574
#     ✓ Accepted: pix 189, z_abs=2.040, τ=0.4511
#     ✓ Accepted: pix 195, z_abs=2.128, τ=1.0490
#     ✓ Accepted: pix 198, z_abs=2.173, τ=0.2294
#     ✓ Accepted: pix 203, z_abs=2.249, τ=1.0170
#     ✓ Accepted: pix 208, z_abs=2.327, τ=0.0690
#     ✓ Accepted: pix 212, z_abs=2.390, τ=0.4239
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.840727]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [184 187 192 200 206 210]
#     Tau values: [0.22397444 0.6450499  0.8215407  0.8407274  0.1059294  0.26168564]
#     ✓ Accepted: pix 184, z_abs=1.971, τ=0.2240
#     ✓ Accepted: pix 187, z_abs=2.013, τ=0.6450
#     ✓ Accepted: pix 192, z_abs=2.086, τ=0.8215
#     ✓ Accepted: pix 200, z_abs=2.205, τ=0.8407
#     ✓ Accepted: pix 206, z_abs=2.298, τ=0.1059
#     ✓ Accepted: pix 210, z_abs=2.361, τ=0.2617
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.017431]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 188 192 195 200 207 211]
#     Tau values: [0.53968287 0.8726859  0.02087038 0.177611   1.0174308  0.39706174
#  0.2789438 ]
#     ✓ Accepted: pix 184, z_abs=1.971, τ=0.5397
#     ✓ Accepted: pix 188, z_abs=2.028, τ=0.8727
#     ✓ Accepted: pix 192, z_abs=2.086, τ=0.0209
#     ✓ Accepted: pix 195, z_abs=2.130, τ=0.1776
#     ✓ Accepted: pix 200, z_abs=2.205, τ=1.0174
#     ✓ Accepted: pix 207, z_abs=2.314, τ=0.3971
#     ✓ Accepted: pix 211, z_abs=2.377, τ=0.2789
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.941506]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 190 193 197 203 209 212]
#     Tau values: [0.9415063  0.846166   0.30490574 0.44944626 0.42201    0.05974384
#  0.06466127]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.9415
#     ✓ Accepted: pix 190, z_abs=2.058, τ=0.8462
#     ✓ Accepted: pix 193, z_abs=2.102, τ=0.3049
#     ✓ Accepted: pix 197, z_abs=2.161, τ=0.4494
#     ✓ Accepted: pix 203, z_abs=2.252, τ=0.4220
#     ✓ Accepted: pix 209, z_abs=2.346, τ=0.0597
#     ✓ Accepted: pix 212, z_abs=2.394, τ=0.0647
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.009856]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 190 195 198 201 207 211]
#     Tau values: [0.22499412 0.7916189  1.0098555  0.13202254 0.5950036  0.14295116
#  0.6416726 ]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.2250
#     ✓ Accepted: pix 190, z_abs=2.057, τ=0.7916
#     ✓ Accepted: pix 195, z_abs=2.131, τ=1.0099
#     ✓ Accepted: pix 198, z_abs=2.175, τ=0.1320
#     ✓ Accepted: pix 201, z_abs=2.221, τ=0.5950
#     ✓ Accepted: pix 207, z_abs=2.314, τ=0.1430
#     ✓ Accepted: pix 211, z_abs=2.377, τ=0.6417
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.544929]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [185 191 195 199 202 208 212]
#     Tau values: [0.48885107 0.02524015 0.22887212 0.06093714 0.09841431 0.54492944
#  0.01940143]
#     ✓ Accepted: pix 185, z_abs=1.987, τ=0.4889
#     ✓ Accepted: pix 191, z_abs=2.073, τ=0.0252
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.2289
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.0609
#     ✓ Accepted: pix 202, z_abs=2.238, τ=0.0984
#     ✓ Accepted: pix 208, z_abs=2.331, τ=0.5449
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.0194
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.722596]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 189 192 195 199 203 211]
#     Tau values: [0.02022024 0.7225957  0.6685292  0.13146539 0.0168407  0.18907875
#  0.61835474]
#     ✓ Accepted: pix 184, z_abs=1.973, τ=0.0202
#     ✓ Accepted: pix 189, z_abs=2.044, τ=0.7226
#     ✓ Accepted: pix 192, z_abs=2.087, τ=0.6685
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.1315
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.0168
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.1891
#     ✓ Accepted: pix 211, z_abs=2.378, τ=0.6184
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.817108]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [184 187 193 197 200 203 208 211]
#     Tau values: [0.01045986 0.17173952 0.04163606 0.03568908 0.4231601  0.81710756
#  0.11483591 0.06304418]
#     ✓ Accepted: pix 184, z_abs=1.971, τ=0.0105
#     ✓ Accepted: pix 187, z_abs=2.014, τ=0.1717
#     ✓ Accepted: pix 193, z_abs=2.101, τ=0.0416
#     ✓ Accepted: pix 197, z_abs=2.160, τ=0.0357
#     ✓ Accepted: pix 200, z_abs=2.205, τ=0.4232
#     ✓ Accepted: pix 203, z_abs=2.251, τ=0.8171
#     ✓ Accepted: pix 208, z_abs=2.329, τ=0.1148
#     ✓ Accepted: pix 211, z_abs=2.377, τ=0.0630
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.040581]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [188 193 197 201 204 207 211]
#     Tau values: [0.27527604 0.32202196 0.11132071 0.6028951  0.10917517 0.23156743
#  1.0405813 ]
#     ✓ Accepted: pix 188, z_abs=2.028, τ=0.2753
#     ✓ Accepted: pix 193, z_abs=2.101, τ=0.3220
#     ✓ Accepted: pix 197, z_abs=2.160, τ=0.1113
#     ✓ Accepted: pix 201, z_abs=2.221, τ=0.6029
#     ✓ Accepted: pix 204, z_abs=2.267, τ=0.1092
#     ✓ Accepted: pix 207, z_abs=2.314, τ=0.2316
#     ✓ Accepted: pix 211, z_abs=2.377, τ=1.0406
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.986256]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [185 189 192 195 199 202 208 212]
#     Tau values: [0.86946213 0.40757957 0.88870776 0.74024236 0.8988011  0.986256
#  0.04122015 0.02247536]
#     ✓ Accepted: pix 185, z_abs=1.987, τ=0.8695
#     ✓ Accepted: pix 189, z_abs=2.044, τ=0.4076
#     ✓ Accepted: pix 192, z_abs=2.088, τ=0.8887
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.7402
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.8988
#     ✓ Accepted: pix 202, z_abs=2.237, τ=0.9863
#     ✓ Accepted: pix 208, z_abs=2.331, τ=0.0412
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.0225
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.002342]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [185 188 193 197 200 203 208]
#     Tau values: [0.5165719  0.4373134  0.21617146 0.7054659  0.39648223 1.0023421
#  0.8592051 ]
#     ✓ Accepted: pix 185, z_abs=1.985, τ=0.5166
#     ✓ Accepted: pix 188, z_abs=2.028, τ=0.4373
#     ✓ Accepted: pix 193, z_abs=2.100, τ=0.2162
#     ✓ Accepted: pix 197, z_abs=2.160, τ=0.7055
#     ✓ Accepted: pix 200, z_abs=2.205, τ=0.3965
#     ✓ Accepted: pix 203, z_abs=2.251, τ=1.0023
#     ✓ Accepted: pix 208, z_abs=2.329, τ=0.8592
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.891878]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [186 191 196 199 206 210]
#     Tau values: [0.20140076 0.48296392 0.68103206 0.26446518 0.47188908 0.8918779 ]
#     ✓ Accepted: pix 186, z_abs=2.000, τ=0.2014
#     ✓ Accepted: pix 191, z_abs=2.072, τ=0.4830
#     ✓ Accepted: pix 196, z_abs=2.145, τ=0.6810
#     ✓ Accepted: pix 199, z_abs=2.191, τ=0.2645
#     ✓ Accepted: pix 206, z_abs=2.298, τ=0.4719
#     ✓ Accepted: pix 210, z_abs=2.361, τ=0.8919
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.731423]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [185 189 196 200 205 210]
#     Tau values: [0.17695892 0.01885476 0.3976051  0.081673   0.14078778 0.73142284]
#     ✓ Accepted: pix 185, z_abs=1.985, τ=0.1770
#     ✓ Accepted: pix 189, z_abs=2.042, τ=0.0189
#     ✓ Accepted: pix 196, z_abs=2.145, τ=0.3976
#     ✓ Accepted: pix 200, z_abs=2.205, τ=0.0817
#     ✓ Accepted: pix 205, z_abs=2.282, τ=0.1408
#     ✓ Accepted: pix 210, z_abs=2.361, τ=0.7314
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.981665]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 191 195 199 203 207 210]
#     Tau values: [0.08666504 0.05129827 0.12204942 0.98166543 0.6892354  0.04743358
#  0.12890348]
#     ✓ Accepted: pix 186, z_abs=2.001, τ=0.0867
#     ✓ Accepted: pix 191, z_abs=2.073, τ=0.0513
#     ✓ Accepted: pix 195, z_abs=2.132, τ=0.1220
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.9817
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.6892
#     ✓ Accepted: pix 207, z_abs=2.315, τ=0.0474
#     ✓ Accepted: pix 210, z_abs=2.363, τ=0.1289
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.642814]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [184 191 194 199 202 205 208 211]
#     Tau values: [0.12233247 0.6428139  0.02392687 0.2591032  0.34987205 0.15611252
#  0.1385249  0.59382546]
#     ✓ Accepted: pix 184, z_abs=1.973, τ=0.1223
#     ✓ Accepted: pix 191, z_abs=2.073, τ=0.6428
#     ✓ Accepted: pix 194, z_abs=2.117, τ=0.0239
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.2591
#     ✓ Accepted: pix 202, z_abs=2.237, τ=0.3499
#     ✓ Accepted: pix 205, z_abs=2.284, τ=0.1561
#     ✓ Accepted: pix 208, z_abs=2.331, τ=0.1385
#     ✓ Accepted: pix 211, z_abs=2.378, τ=0.5938
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.100236]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [184 189 192 197 203 206 210]
#     Tau values: [0.6814609  0.11181192 0.04363329 0.4463946  0.04157909 1.0503827
#  1.1002359 ]
#     ✓ Accepted: pix 184, z_abs=1.972, τ=0.6815
#     ✓ Accepted: pix 189, z_abs=2.043, τ=0.1118
#     ✓ Accepted: pix 192, z_abs=2.087, τ=0.0436
#     ✓ Accepted: pix 197, z_abs=2.161, τ=0.4464
#     ✓ Accepted: pix 203, z_abs=2.252, τ=0.0416
#     ✓ Accepted: pix 206, z_abs=2.299, τ=1.0504
#     ✓ Accepted: pix 210, z_abs=2.362, τ=1.1002
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.047404]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [186 189 194 200 203 209 212]
#     Tau values: [0.28372246 0.12089383 0.24181409 0.54198515 0.600105   1.0474036
#  0.03113811]
#     ✓ Accepted: pix 186, z_abs=2.001, τ=0.2837
#     ✓ Accepted: pix 189, z_abs=2.043, τ=0.1209
#     ✓ Accepted: pix 194, z_abs=2.116, τ=0.2418
#     ✓ Accepted: pix 200, z_abs=2.206, τ=0.5420
#     ✓ Accepted: pix 203, z_abs=2.252, τ=0.6001
#     ✓ Accepted: pix 209, z_abs=2.346, τ=1.0474
#     ✓ Accepted: pix 212, z_abs=2.394, τ=0.0311
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.958770]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [186 192 199 203 209 212]
#     Tau values: [0.3049609  0.21286732 0.38392103 0.12886927 0.9587695  0.16373718]
#     ✓ Accepted: pix 186, z_abs=2.001, τ=0.3050
#     ✓ Accepted: pix 192, z_abs=2.088, τ=0.2129
#     ✓ Accepted: pix 199, z_abs=2.192, τ=0.3839
#     ✓ Accepted: pix 203, z_abs=2.253, τ=0.1289
#     ✓ Accepted: pix 209, z_abs=2.347, τ=0.9588
#     ✓ Accepted: pix 212, z_abs=2.395, τ=0.1637
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.720299]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [184 190 193 198 204 208]
#     Tau values: [0.14057276 0.72029877 0.09283195 0.03672915 0.4323557  0.17985052]
#     ✓ Accepted: pix 184, z_abs=1.973, τ=0.1406
#     ✓ Accepted: pix 190, z_abs=2.059, τ=0.7203
#     ✓ Accepted: pix 193, z_abs=2.103, τ=0.0928
#     ✓ Accepted: pix 198, z_abs=2.177, τ=0.0367
#     ✓ Accepted: pix 204, z_abs=2.269, τ=0.4324
#     ✓ Accepted: pix 208, z_abs=2.332, τ=0.1799
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.948359]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [184 191 196 201 205 210]
#     Tau values: [0.30382726 0.9483592  0.19752921 0.37109458 0.6176125  0.6524124 ]
#     ✓ Accepted: pix 184, z_abs=1.975, τ=0.3038
#     ✓ Accepted: pix 191, z_abs=2.075, τ=0.9484
#     ✓ Accepted: pix 196, z_abs=2.149, τ=0.1975
#     ✓ Accepted: pix 201, z_abs=2.224, τ=0.3711
#     ✓ Accepted: pix 205, z_abs=2.286, τ=0.6176
#     ✓ Accepted: pix 210, z_abs=2.365, τ=0.6524
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.955019]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [172 176 181 187 191 195 199 202]
#     Tau values: [0.0231418  0.08885838 0.95501924 0.41673452 0.00798643 0.74587476
#  0.75382835 0.01245814]
#     ✓ Accepted: pix 172, z_abs=1.970, τ=0.0231
#     ✓ Accepted: pix 176, z_abs=2.027, τ=0.0889
#     ✓ Accepted: pix 181, z_abs=2.100, τ=0.9550
#     ✓ Accepted: pix 187, z_abs=2.189, τ=0.4167
#     ✓ Accepted: pix 191, z_abs=2.250, τ=0.0080
#     ✓ Accepted: pix 195, z_abs=2.313, τ=0.7459
#     ✓ Accepted: pix 199, z_abs=2.376, τ=0.7538
#     ✓ Accepted: pix 202, z_abs=2.424, τ=0.0125
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.880978]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [173 177 182 186 194 197 200]
#     Tau values: [0.5408702  0.06838933 0.43645614 0.88097787 0.16531008 0.1394518
#  0.3048189 ]
#     ✓ Accepted: pix 173, z_abs=1.986, τ=0.5409
#     ✓ Accepted: pix 177, z_abs=2.044, τ=0.0684
#     ✓ Accepted: pix 182, z_abs=2.117, τ=0.4365
#     ✓ Accepted: pix 186, z_abs=2.176, τ=0.8810
#     ✓ Accepted: pix 194, z_abs=2.299, τ=0.1653
#     ✓ Accepted: pix 197, z_abs=2.346, τ=0.1395
#     ✓ Accepted: pix 200, z_abs=2.394, τ=0.3048
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.903187]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [174 179 183 186 189 192 195 198]
#     Tau values: [0.7703892  0.47566998 0.100088   0.45715627 0.21735896 0.0952649
#  0.3100852  0.9031872 ]
#     ✓ Accepted: pix 174, z_abs=2.001, τ=0.7704
#     ✓ Accepted: pix 179, z_abs=2.073, τ=0.4757
#     ✓ Accepted: pix 183, z_abs=2.132, τ=0.1001
#     ✓ Accepted: pix 186, z_abs=2.177, τ=0.4572
#     ✓ Accepted: pix 189, z_abs=2.223, τ=0.2174
#     ✓ Accepted: pix 192, z_abs=2.269, τ=0.0953
#     ✓ Accepted: pix 195, z_abs=2.316, τ=0.3101
#     ✓ Accepted: pix 198, z_abs=2.363, τ=0.9032
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.052744]
#   Noise level: 0.000100
#   Raw peaks found: 6
#     Pixels: [173 181 186 189 195 200]
#     Tau values: [0.79010874 0.4088442  0.97960407 0.6626118  1.0527438  0.94422215]
#     ✓ Accepted: pix 173, z_abs=1.986, τ=0.7901
#     ✓ Accepted: pix 181, z_abs=2.102, τ=0.4088
#     ✓ Accepted: pix 186, z_abs=2.176, τ=0.9796
#     ✓ Accepted: pix 189, z_abs=2.221, τ=0.6626
#     ✓ Accepted: pix 195, z_abs=2.314, τ=1.0527
#     ✓ Accepted: pix 200, z_abs=2.394, τ=0.9442
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.702575]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [175 178 183 186 189 194 201]
#     Tau values: [0.7025747  0.05687254 0.48273703 0.378294   0.68983984 0.39932498
#  0.2908162 ]
#     ✓ Accepted: pix 175, z_abs=2.014, τ=0.7026
#     ✓ Accepted: pix 178, z_abs=2.057, τ=0.0569
#     ✓ Accepted: pix 183, z_abs=2.130, τ=0.4827
#     ✓ Accepted: pix 186, z_abs=2.175, τ=0.3783
#     ✓ Accepted: pix 189, z_abs=2.221, τ=0.6898
#     ✓ Accepted: pix 194, z_abs=2.298, τ=0.3993
#     ✓ Accepted: pix 201, z_abs=2.409, τ=0.2908
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.902198]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [174 178 181 184 190 193 199 202]
#     Tau values: [0.2671589  0.5975059  0.6418914  0.04159763 0.45830122 0.19999659
#  0.902198   0.33905336]
#     ✓ Accepted: pix 174, z_abs=2.000, τ=0.2672
#     ✓ Accepted: pix 178, z_abs=2.058, τ=0.5975
#     ✓ Accepted: pix 181, z_abs=2.101, τ=0.6419
#     ✓ Accepted: pix 184, z_abs=2.146, τ=0.0416
#     ✓ Accepted: pix 190, z_abs=2.237, τ=0.4583
#     ✓ Accepted: pix 193, z_abs=2.283, τ=0.2000
#     ✓ Accepted: pix 199, z_abs=2.378, τ=0.9022
#     ✓ Accepted: pix 202, z_abs=2.426, τ=0.3391
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.733452]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [173 177 181 185 189 194 197 200]
#     Tau values: [0.34587944 0.01960134 0.4134664  0.733452   0.22405541 0.5652099
#  0.11457943 0.16040985]
#     ✓ Accepted: pix 173, z_abs=1.987, τ=0.3459
#     ✓ Accepted: pix 177, z_abs=2.044, τ=0.0196
#     ✓ Accepted: pix 181, z_abs=2.102, τ=0.4135
#     ✓ Accepted: pix 185, z_abs=2.162, τ=0.7335
#     ✓ Accepted: pix 189, z_abs=2.222, τ=0.2241
#     ✓ Accepted: pix 194, z_abs=2.300, τ=0.5652
#     ✓ Accepted: pix 197, z_abs=2.347, τ=0.1146
#     ✓ Accepted: pix 200, z_abs=2.395, τ=0.1604
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.946923]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [172 177 181 184 187 192 196 199]
#     Tau values: [0.15306635 0.8503415  0.22925152 0.19587958 0.84894174 0.1769906
#  0.24680519 0.9469226 ]
#     ✓ Accepted: pix 172, z_abs=1.972, τ=0.1531
#     ✓ Accepted: pix 177, z_abs=2.044, τ=0.8503
#     ✓ Accepted: pix 181, z_abs=2.102, τ=0.2293
#     ✓ Accepted: pix 184, z_abs=2.146, τ=0.1959
#     ✓ Accepted: pix 187, z_abs=2.191, τ=0.8489
#     ✓ Accepted: pix 192, z_abs=2.268, τ=0.1770
#     ✓ Accepted: pix 196, z_abs=2.331, τ=0.2468
#     ✓ Accepted: pix 199, z_abs=2.378, τ=0.9469
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.878816]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [172 176 180 183 187 190 196 199]
#     Tau values: [0.4079219  0.1655469  0.06534788 0.47198808 0.8788157  0.11367591
#  0.28560138 0.6340895 ]
#     ✓ Accepted: pix 172, z_abs=1.973, τ=0.4079
#     ✓ Accepted: pix 176, z_abs=2.030, τ=0.1655
#     ✓ Accepted: pix 180, z_abs=2.088, τ=0.0653
#     ✓ Accepted: pix 183, z_abs=2.132, τ=0.4720
#     ✓ Accepted: pix 187, z_abs=2.192, τ=0.8788
#     ✓ Accepted: pix 190, z_abs=2.237, τ=0.1137
#     ✓ Accepted: pix 196, z_abs=2.331, τ=0.2856
#     ✓ Accepted: pix 199, z_abs=2.378, τ=0.6341
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.863436]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [174 177 185 188 194 199 202]
#     Tau values: [0.2288737  0.46027026 0.10131649 0.2009971  0.8634362  0.18883179
#  0.42994636]
#     ✓ Accepted: pix 174, z_abs=2.002, τ=0.2289
#     ✓ Accepted: pix 177, z_abs=2.045, τ=0.4603
#     ✓ Accepted: pix 185, z_abs=2.162, τ=0.1013
#     ✓ Accepted: pix 188, z_abs=2.208, τ=0.2010
#     ✓ Accepted: pix 194, z_abs=2.300, τ=0.8634
#     ✓ Accepted: pix 199, z_abs=2.379, τ=0.1888
#     ✓ Accepted: pix 202, z_abs=2.428, τ=0.4299
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.842757]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [172 178 181 187 191 196 200]
#     Tau values: [0.8162383  0.3407503  0.07623376 0.842757   0.22487804 0.63737583
#  0.48876286]
#     ✓ Accepted: pix 172, z_abs=1.977, τ=0.8162
#     ✓ Accepted: pix 178, z_abs=2.063, τ=0.3408
#     ✓ Accepted: pix 181, z_abs=2.107, τ=0.0762
#     ✓ Accepted: pix 187, z_abs=2.196, τ=0.8428
#     ✓ Accepted: pix 191, z_abs=2.257, τ=0.2249
#     ✓ Accepted: pix 196, z_abs=2.335, τ=0.6374
#     ✓ Accepted: pix 200, z_abs=2.399, τ=0.4888
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.890942]
#   Noise level: 0.000100
#   Raw peaks found: 8
#     Pixels: [174 179 183 186 189 194 198 202]
#     Tau values: [0.89094204 0.41449165 0.3706936  0.29482773 0.50475705 0.15709028
#  0.1652253  0.8488088 ]
#     ✓ Accepted: pix 174, z_abs=2.002, τ=0.8909
#     ✓ Accepted: pix 179, z_abs=2.074, τ=0.4145
#     ✓ Accepted: pix 183, z_abs=2.132, τ=0.3707
#     ✓ Accepted: pix 186, z_abs=2.177, τ=0.2948
#     ✓ Accepted: pix 189, z_abs=2.223, τ=0.5048
#     ✓ Accepted: pix 194, z_abs=2.300, τ=0.1571
#     ✓ Accepted: pix 198, z_abs=2.363, τ=0.1652
#     ✓ Accepted: pix 202, z_abs=2.428, τ=0.8488
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.944208]
#   Noise level: 0.000100
#   Raw peaks found: 9
#     Pixels: [172 177 181 185 188 193 196 199 202]
#     Tau values: [0.8153141  0.89353645 0.8297915  0.4824126  0.5889542  0.7534301
#  0.32038426 0.13422424 0.9442077 ]
#     ✓ Accepted: pix 172, z_abs=1.972, τ=0.8153
#     ✓ Accepted: pix 177, z_abs=2.044, τ=0.8935
#     ✓ Accepted: pix 181, z_abs=2.102, τ=0.8298
#     ✓ Accepted: pix 185, z_abs=2.161, τ=0.4824
#     ✓ Accepted: pix 188, z_abs=2.207, τ=0.5890
#     ✓ Accepted: pix 193, z_abs=2.284, τ=0.7534
#     ✓ Accepted: pix 196, z_abs=2.331, τ=0.3204
#     ✓ Accepted: pix 199, z_abs=2.378, τ=0.1342
#     ✓ Accepted: pix 202, z_abs=2.427, τ=0.9442
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 1.008644]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [174 178 182 187 191 194 200]
#     Tau values: [0.7661572  0.8401256  0.41503304 0.9723757  0.34104446 0.7803275
#  1.0086443 ]
#     ✓ Accepted: pix 174, z_abs=2.001, τ=0.7662
#     ✓ Accepted: pix 178, z_abs=2.059, τ=0.8401
#     ✓ Accepted: pix 182, z_abs=2.117, τ=0.4150
#     ✓ Accepted: pix 187, z_abs=2.192, τ=0.9724
#     ✓ Accepted: pix 191, z_abs=2.253, τ=0.3410
#     ✓ Accepted: pix 194, z_abs=2.300, τ=0.7803
#     ✓ Accepted: pix 200, z_abs=2.395, τ=1.0086
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.870502]
#   Noise level: 0.000100
#   Raw peaks found: 9
#     Pixels: [172 175 178 181 187 190 193 196 202]
#     Tau values: [0.5485882  0.09388094 0.39210528 0.8348338  0.62285787 0.8705018
#  0.09192099 0.5542337  0.12447248]
#     ✓ Accepted: pix 172, z_abs=1.973, τ=0.5486
#     ✓ Accepted: pix 175, z_abs=2.016, τ=0.0939
#     ✓ Accepted: pix 178, z_abs=2.059, τ=0.3921
#     ✓ Accepted: pix 181, z_abs=2.103, τ=0.8348
#     ✓ Accepted: pix 187, z_abs=2.192, τ=0.6229
#     ✓ Accepted: pix 190, z_abs=2.238, τ=0.8705
#     ✓ Accepted: pix 193, z_abs=2.284, τ=0.0919
#     ✓ Accepted: pix 196, z_abs=2.331, τ=0.5542
#     ✓ Accepted: pix 202, z_abs=2.427, τ=0.1245
# /tmp/ipykernel_2127558/177742671.py:16: RuntimeWarning: overflow encountered in exp
#   probs = 1.0 / (1.0 + np.exp(-detect_logits))  # sigmoid
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.547368]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [172 176 180 186 192 197 202]
#     Tau values: [0.05328169 0.12494934 0.41461855 0.07607985 0.27952263 0.54736805
#  0.01314444]
#     ✓ Accepted: pix 172, z_abs=1.976, τ=0.0533
#     ✓ Accepted: pix 176, z_abs=2.033, τ=0.1249
#     ✓ Accepted: pix 180, z_abs=2.091, τ=0.4146
#     ✓ Accepted: pix 186, z_abs=2.180, τ=0.0761
#     ✓ Accepted: pix 192, z_abs=2.272, τ=0.2795
#     ✓ Accepted: pix 197, z_abs=2.350, τ=0.5474
#     ✓ Accepted: pix 202, z_abs=2.431, τ=0.0131
#
# MgI(2853):
#   Metal rest wave: 2852.96 Å
#   Metal pixel: 212
#   REST_GRID[212]: 2847.83 Å
#   Signal region: pixels 0 to 213
#   Signal tau range: [0.000000, 0.657540]
#   Noise level: 0.000100
#   Raw peaks found: 7
#     Pixels: [173 181 184 189 192 196 201]
#     Tau values: [0.19655341 0.4756182  0.65753967 0.13878754 0.29374984 0.45940456
#  0.6128232 ]
#     ✓ Accepted: pix 173, z_abs=1.988, τ=0.1966
#     ✓ Accepted: pix 181, z_abs=2.103, τ=0.4756
# ...
#          5.72627698e-02, -1.09899515e-01,  8.19921004e-01, -1.67198317e-01,
#         -5.85401310e-01, -5.15632463e-02,  1.80623761e-01,  7.46338212e-01,
#          7.56454608e-01,  2.38994235e-01,  1.43778276e-01,  2.62426487e-01,
#          2.98155922e-01,  2.47709450e-01,  9.93548899e-02,  1.51608549e-01,
#          3.92293242e-01,  9.27631641e-01,  3.73796373e-02, -1.85866626e-01,
#         -1.24213953e-01,  1.49354448e-01,  3.90974543e+00, -7.05866730e-01,
#          2.18325725e-02, -3.58866477e-03,  7.03450442e-01,  2.27642214e-01,
#          6.82287844e-01,  1.49510052e+00,  1.85716876e+00,  5.00618020e-01,
#          3.22516814e-01,  8.16399323e-02,  5.25195059e-02,  2.40458956e-02,
#          1.02791538e+00,  5.35310365e+00,  5.35071349e-01, -2.09216849e-01,
#         -5.60773519e-02, -3.15049914e-02,  2.66228077e-01,  1.35736238e+00,
#          3.91978207e-01,  1.84058173e-01, -1.41852740e-01,  2.33498672e-01,
#          3.83964903e-01,  2.04025763e-01,  1.55255945e+00,  7.48195133e-01,
#         -1.66168970e-01, -4.91252928e-01, -3.64039470e-01, -5.64611812e-01,
#          1.27434989e+00,  3.75882915e-01, -1.98417551e-02, -3.67807053e-01,
#         -1.35042825e+00,  7.51580139e-02,  1.64100146e-01,  1.80982474e+01,
#          1.48869759e-01,  2.47317687e-01,  7.22318967e+00,  1.59028932e-01,
#          1.75181116e-01,  1.65991570e-01, -3.74551637e-01, -3.68050483e-01,
#          8.41172445e-01,  1.41490245e-01, -3.66253854e-02, -8.13953228e-02,
#         -1.30083608e-03,  1.46033528e-01,  1.41191914e-01,  9.40495893e-02,
#          3.72408883e+00,  3.88019652e-02,  1.76203038e-02, -2.06740933e-01,
#         -3.24921675e-02,  7.20921631e-02,  2.39266363e+00,  1.82326124e+00,
#          1.90440453e-01,  3.07066284e-01,  1.35757493e-01,  1.13044173e+00,
#         -6.78024042e-01, -5.20488391e-01,  1.88208060e+00,  3.28264398e-02,
#         -7.52265730e-01, -6.39270869e-01, -1.12820737e+00,  1.17859247e+01,
#          9.85266676e-01, -8.39472559e-01, -2.03027269e-01,  3.00640363e-01,
#         -1.69172033e-02, -1.84713094e-01,  7.07698349e-02,  9.62451237e-02,
#          1.77900624e-02, -1.11305244e-01, -1.88721474e-02, -1.98681720e-01,
#          9.68788657e-01,  6.89084218e-02, -7.85399060e-02, -2.28068676e-01,
#         -1.67358887e-01, -1.55018339e-01, -1.07057760e-01,  4.16357628e-02,
#          2.31801413e-01,  4.40009718e-01,  2.17854465e-01, -1.94385240e-01,
#         -2.14577936e-01, -4.15117812e-02,  8.52916952e-02,  5.42131601e-02,
#          1.22984061e+00, -9.23502366e-02,  1.30457182e-01,  6.00497403e-02,
#         -9.09889636e-02, -6.16697739e-01,  7.49390285e-01,  2.15428568e-01,
#          1.13417302e-01,  5.56945225e-01, -1.22290869e-01,  3.20800489e-02,
#         -3.55770309e-01,  3.29959160e-01,  2.99921747e+00,  3.41275043e-01,
#          1.06148654e+00,  3.21067909e+00,  9.56505664e+00,  2.67936868e-02,
#          3.70209746e-01,  3.59005107e-01,  3.97302861e-01,  3.88930102e-01,
#         -3.39489982e-02,  2.30664770e-01,  1.84022325e-02, -7.93126172e-01,
#         -2.40924935e-01, -1.94667466e-01, -4.79069296e-01, -1.21471170e-02,
#          1.65854054e+01,  5.91742568e-01,  5.21631319e-02,  1.10071805e-01,
#          2.07366650e-01,  4.06317240e-01, -2.95051913e-01,  1.03411439e-01,
#         -8.00999497e-01, -3.07055798e-01,  1.98192766e+00,  2.04718643e+00,
#          5.11306443e-01, -6.99382550e-01,  4.66704425e-01, -1.43865270e-01,
#         -2.11676511e-01, -2.15001658e-01,  3.91136966e-01,  5.03035175e-01,
#          9.97909705e-01,  2.23957120e-01,  4.15497609e-01,  2.81744325e-01,
#         -8.18622698e-02,  3.22506063e-02,  1.15833650e-01, -1.64169501e-01,
#          4.46800623e+00,  5.73962192e+01,  6.12598428e-02,  1.40582032e-01,
#         -1.68445288e-01, -1.02210218e-01, -1.16073306e-03,  1.47073473e-01,
#          7.82165288e-02,  1.74553585e-01, -3.44338136e-01,  8.32022883e-02,
#          5.49373214e-01, -1.60238515e-01,  4.63834351e-01,  1.03900676e+00,
#          2.40840413e+00, -3.90538804e-01, -4.08238551e-01,  9.20150458e-03,
#          1.90315208e-01,  3.66056797e+00,  7.60807859e+00,  1.55039310e+00,
#          5.68671102e-02,  5.51534077e-01,  5.03123518e+00,  6.82249908e+00,
#          2.09216577e-01, -2.26139449e-01, -3.55757155e-01, -3.92882425e-01,
#         -4.17715692e-01, -4.57201324e-01,  5.59137143e-02,  7.23371296e-01,
#          9.66255140e-01,  3.18145190e+00,  1.07036739e-02, -3.53822214e-01,
#          3.80734167e-01,  6.98227893e-02,  7.03219221e-02, -2.59078619e-01,
#         -5.51167452e-01, -1.05455296e-01, -8.41455945e-02,  1.56311327e-01,
#          1.30269456e-01,  3.62582772e-01, -1.31446972e-01, -2.91709838e-01,
#         -2.13447659e-01,  3.00747580e-01,  2.36082300e-01,  4.94994077e-01,
#         -5.58568600e-01,  1.01019338e-02,  1.11786689e-01, -4.12272939e-01,
#         -4.03341483e-01, -1.74983820e-01,  4.47905526e-01, -3.34479626e-02,
#         -1.82242537e-01,  1.71700363e-01, -8.09089788e-03,  5.24115617e-02,
#          7.90779019e+00,  6.85133469e+00, -2.25583805e-01, -1.10494706e-01,
#          1.51435832e+00,  1.73433549e-01,  1.75520128e-01,  2.85624465e-01,
#          6.55493472e-02, -7.45781062e-02, -1.25697798e-01, -8.58390288e-02,
#         -5.37321265e-01,  2.63658399e-01,  4.99220556e-01,  3.20964697e-02,
#          4.44030239e-01, -1.04197483e-01, -2.83861835e-01, -4.22645993e-01,
#         -5.57267182e-01, -3.77767953e-01, -2.66672385e-01, -9.41935797e-02,
#         -6.65820470e-02, -3.21486226e-02,  7.56158886e-02,  3.09471533e-01,
#          3.41477862e-01, -6.59475032e-02, -3.96682234e-01, -3.70379527e-01,
#         -3.71461070e-01, -3.78650230e-01, -3.62136665e-01, -6.23004849e-01,
#         -4.51797764e-01,  8.96795491e-03,  3.34123067e-01,  8.21842261e-01,
#         -2.14274720e-01, -4.44396094e-01, -1.63756698e-01,  1.11785086e+00,
#         -4.52849151e-01, -6.32104556e-01, -6.47917297e-02, -1.23892488e-01,
#         -3.49116828e-01, -2.12254110e-02,  1.25184663e-01, -5.48944991e-01,
#          1.78242867e+00,  1.07830435e-01,  2.54640926e-01, -1.52599521e-01,
#         -1.06303562e-01,  1.77885008e-01, -9.64548451e-02,  4.53910516e-01,
#         -4.89499939e-01, -6.27701438e-01, -8.35724917e-01, -4.41179436e-01,
#         -2.56480818e-01, -4.44531542e-01, -1.26366286e-01, -3.18555470e-01,
#         -4.70103153e-01, -2.19737952e-01, -8.14541471e-01, -3.65448044e-01,
#          2.63015853e-03,  1.13604336e-01, -6.02565278e-01,  1.05694442e-01,
#          9.82587520e-02,  1.82409829e-02, -2.73731747e-01, -1.98688313e-01,
#         -2.10291776e-01, -1.50960123e-01,  5.60010878e-02,  2.92224230e-01,
#          1.84190734e-01,  3.33862717e-02,  2.51969397e-02,  4.78296774e-01,
#         -3.46000040e-01, -1.64255232e-01,  5.18036619e-01,  4.38394117e-02,
#          9.41089324e-02, -8.38712044e-02, -3.07628439e-01, -3.22010274e-01,
#         -2.68149469e-01, -2.40049972e-01,  2.09623386e-02,  2.77208680e-01,
#         -1.89928717e-01, -1.17998147e-01, -9.75596066e-02, -1.67873578e-01,
#          1.06051570e-02, -1.75313422e-01,  1.44089499e-01,  1.28849933e-02,
#         -1.37402504e-01, -1.72915573e-01, -1.48738736e-01, -5.68565132e-03,
#          3.84126411e-01,  2.89775871e-01, -2.14525409e-01,  2.27323225e-01,
#         -7.08205953e-02,  2.56797660e-01,  2.11077659e-02, -1.08543426e+00,
#          1.38447673e-01, -2.77800069e-01, -8.55004261e-02, -1.54421644e-01,
#         -3.52699269e-01, -7.36070249e-02, -6.70935022e-02, -2.86359038e-01,
#         -3.38949895e-02, -1.84892188e-01, -1.63823263e-01,  1.37649445e-02,
#         -1.16609890e-02,  8.67952225e-02,  4.93841317e-01, -7.34112626e-01,
#         -6.54592477e-01, -4.89163275e-01, -1.45802871e-01,  8.86687771e-03,
#         -8.78631685e-02,  9.53013016e-04, -5.88529705e-01, -1.37185692e-01,
#          4.38539175e-01,  1.05626565e+00,  3.42679436e-01,  1.25698589e-01,
#          6.09509392e-01,  3.72776299e+00,  6.48061506e+00, -2.48733160e-01,
#         -2.22715764e-01,  1.14853780e-02,  6.50823512e-03,  1.42295393e-01,
#          8.96073174e-02, -8.23776930e-02,  2.64130990e-01,  3.50572164e-01,
#          3.36854834e-01,  4.04970301e-01,  2.64573567e-02, -1.08186197e-01,
#          6.49991984e-02,  1.99654466e+00,  5.88735461e-02, -4.11019341e-01,
#         -1.29112265e-01, -1.86811080e-01, -1.97515991e-01, -7.61168862e-02,
#         -1.82253751e-02,  5.62275566e-02,  1.68544395e-02,  2.68813308e+00,
#         -2.74126502e-03, -7.65443261e-02,  3.37467947e-01,  9.04617891e-02,
#         -2.02231975e-01, -2.76070128e-01, -2.28651880e-01,  2.56030902e-01,
#         -3.40309128e-02, -1.08264841e-01, -2.45394496e-02, -2.86245288e-01,
#         -2.01477657e-01, -1.14394445e-01, -3.03497814e-01,  3.10421198e-02,
#          1.65469146e-01, -4.80271069e-01,  1.14593156e-01,  3.50153064e-01,
#         -7.61066755e-01, -3.44434113e-01,  2.18210663e-01, -9.73237064e-02,
#         -1.70824286e-01, -1.00527120e-01,  8.89710945e-02, -7.25731740e-01,
#          2.89306769e+00,  1.25570494e+00, -5.40211287e-01,  5.68727793e-01,
#          2.00580345e-01,  1.07678258e-02,  1.59828537e+00, -1.65766360e-01,
#          3.18569753e-01,  5.59805868e-01,  5.55208179e-02,  5.01081127e-01,
#          4.76871947e-01,  1.08397335e+00,  5.41084742e-01,  7.78752078e-01,
#         -4.71098120e-02,  3.38208493e-03, -5.32336719e-01,  5.68799801e-01,
#          1.62385952e-01, -5.39202774e-02,  2.81862810e-02, -9.75341071e-02,
#          1.31363458e-01,  5.60407682e-01,  5.70897756e+00,  1.84167055e-01,
#         -2.44481962e-02,  2.30288446e-01, -8.22568350e-02, -5.22001918e-01,
#          6.19839610e-02,  1.47430432e-01, -1.11773877e-01, -2.49360392e-01,
#         -5.82513576e-03, -2.58150383e-01, -1.55567892e-01,  1.50566152e-01,
#         -6.01983997e-02, -1.70914574e-02,  3.91957112e-02,  1.05881719e-01,
#         -4.71669422e-02,  1.46502414e-01, -2.12952949e-01, -5.09762861e-01,
#         -6.91470586e-01,  4.11960168e-01,  4.41560613e-01, -1.44131500e-01,
#          3.44773794e-01, -6.10002935e-01,  1.78553495e-01, -7.42230833e-01,
#         -5.96124124e-01, -2.93191043e-01, -7.31943858e-03,  1.99710434e-01,
#          3.21545156e-02, -9.82611792e-02, -1.50625899e-01, -5.63504371e-01,
#          5.10443492e-02, -1.12518007e-02, -6.94665160e-01, -6.19185194e-01,
#         -1.11336215e-01, -1.48675052e-01, -2.37802070e-01, -1.03795706e-01,
#          2.76907953e-01,  1.34849697e-01,  1.36907455e-01,  5.68055987e-02,
#         -4.65866522e-01,  4.75439236e-02,  1.07482231e+00, -1.58820377e-01,
#         -4.27645233e-03, -1.48393546e-02, -4.12492997e-01, -3.51242531e-01,
#         -3.09430788e-01, -7.64863856e-02, -3.53824260e-01, -9.58791587e-01,
#         -5.86229597e-01, -6.39976177e-01,  1.68331182e+00,  2.29719880e-02,
#          4.85651904e-01,  3.65903031e-01, -2.96590889e-01,  9.66698292e-01,
#          1.55229081e+00,  4.17165684e-01, -2.13438190e-01, -4.12544306e-01,
#         -1.19962582e-01, -9.13924270e-02, -5.62574025e-02, -1.07447332e-01,
#         -1.46772840e-01, -3.75536754e-01, -4.48935432e-01, -8.61797149e-02,
#          1.19598049e-01, -1.93826463e-01,  3.73334639e-01, -2.78999469e-02,
#         -1.78765810e-01, -7.15173506e-01,  3.90889962e-01,  4.93712438e-01,
#         -3.36010853e-01, -1.63003434e-01,  1.23592656e-02, -9.42984058e-02,
#         -2.18722778e-02,  1.16465527e-01,  1.46044129e-01,  5.56431325e-01,
#         -1.11745787e-02, -6.50685504e-01, -4.87040454e-01, -8.22056582e-01,
#          1.66573117e+00,  1.15517522e+00, -4.07049481e-01,  1.99798339e+00,
#         -4.01897987e-02, -4.56061081e-01, -9.94961802e-03, -5.95551455e-02,
#          3.50687821e-02, -2.88934944e-01, -1.97731545e-01, -1.69383672e-01,
#          9.86694161e-01,  7.24721418e-01,  1.79226720e-02, -7.71916733e-01,
#          5.03771016e-01,  5.99911274e-01,  3.19281684e-01, -3.02412980e-01,
#         -5.39508369e-01, -3.60044913e-01, -2.81716401e-01,  7.37462079e-01,
#          1.39633152e-01, -7.40427788e-02, -9.12073008e-02, -9.31936103e-01,
#         -8.28141795e-01,  3.64905072e-01, -1.61479628e-01, -1.60877182e-01,
#         -1.52271502e-01,  1.56592982e-01,  2.19303839e-01,  1.72950434e-01,
#          9.43370681e-02, -3.35869634e-01, -3.28392764e-01, -3.12667832e-01,
#         -9.98568954e-02, -3.25352630e-02, -6.66915415e-02, -8.45735389e-02,
#          9.82753388e-02,  2.02158493e-01, -2.39671471e-01, -2.15335199e-01,
#         -1.15614809e-01, -2.63114409e-01, -8.81590060e-01, -3.34894270e-01,
#         -1.63019009e-01, -2.08077220e-01, -2.60543443e-01, -4.48251853e-01,
#         -2.75032548e-01, -3.16595762e-01, -7.45495361e-01, -1.17885065e+00,
#         -4.17672792e-01, -1.66033518e-01, -1.52291082e-01, -8.39819339e-02,
#         -3.16937507e-01,  4.26815919e-02,  1.49467194e-01,  6.95979517e-02,
#         -3.92036520e-02, -4.67892496e-02,  6.17891714e-02, -6.15007461e-02,
#          5.35731433e-02,  8.45332922e-02, -5.17188675e-01,  1.60336549e-01,
#         -1.44682262e-01, -3.85669741e-01, -7.01110759e-01,  5.18264410e-01,
#         -3.16595566e-02,  1.74863475e-01,  8.36077059e-02, -4.42110245e-02,
#         -2.86701105e-01, -2.12769035e-01, -3.45352515e-02,  1.07158310e-01,
#         -1.15961207e-01, -3.35416681e-01, -3.60169489e-01, -1.01136527e-01,
#         -6.34862337e-02,  1.14049181e-01,  1.31535083e-01, -6.47957583e-02,
#         -1.50055587e-01, -3.98086324e-01, -3.34392196e-01, -5.04521863e-02,
#          2.02228865e-03,  6.43801581e-01, -2.62609400e-01,  9.38676864e-02,
#         -3.98762381e-02, -4.93656021e-01, -1.87399959e-01, -5.35841131e-02,
#          1.44955536e-02, -1.36020927e-02,  9.30386850e-02, -9.20453999e-02,
#         -4.77594668e-02, -1.44254892e-01, -5.72529011e-01, -1.19804178e+00,
#          2.46246856e+00, -9.10769092e-02, -1.24946760e-01, -3.02145066e-01,
#         -1.16986025e-02, -1.21656445e-01,  2.92925680e-01,  1.26246830e-01,
#          4.31188919e+00, -4.09931543e-01, -1.81199649e-01, -1.50771893e-01,
#         -2.73596333e-02, -1.63577903e-01, -2.27769745e-01, -8.50192810e-02,
#          7.97389586e-01, -1.03832415e-01, -6.89700348e-02, -1.91208400e-01,
#         -4.35880908e-01, -4.77704943e-02, -1.19307490e-01, -9.87851006e-02,
#          6.67296393e-02, -5.68880668e-02, -1.40237927e-01, -2.80068303e-01,
#         -4.04482101e-02,  2.43346269e-02, -3.45477616e-01, -1.38178763e-01,
#         -2.39965362e-01, -1.45815920e-01,  5.16729194e-04, -1.77532924e-01,
#         -3.92824137e-01, -2.45049674e-01,  8.24490460e-03, -9.34950839e-02,
#         -6.17762504e-02, -1.05593314e-01, -4.86751234e-01,  4.04036315e-02,
#         -1.41044438e-01, -3.20716952e-01,  3.55271187e-02, -1.39745847e-01,
#          9.06651542e-02, -1.53398887e-01, -2.10352629e-01, -8.31238333e-02,
#          1.46736770e+00,  6.45001002e-01, -1.08011036e-01, -1.26468669e-01,
#         -1.47812125e-01, -3.49971595e-01, -4.92948640e-02,  1.88199879e-01,
#         -8.90720050e-02, -1.87637232e-01, -1.93460776e-01, -3.16509045e-01,
#         -5.07561381e-01, -2.04300542e-01, -2.46128272e-01, -5.10199855e-01,
#         -1.27848215e-01, -8.49076678e-03, -2.09949861e-01, -3.32884131e-01,
#         -3.40916936e-01, -5.37322130e-01, -5.64797640e-01, -2.77615567e-01,
#         -1.71998755e-01, -6.52297609e-02, -5.23647821e-01, -2.02750818e-01,
#         -1.95287600e-01, -2.13855694e-02, -2.96277395e-01, -1.73221471e-01,
#         -2.09901943e-01, -1.83674070e-01, -2.90177707e-01, -9.53178531e-02,
#         -9.01243528e-02, -3.62399284e-01, -1.87796393e-01, -3.42248031e-01,
#         -2.57019934e-01, -2.21339155e-01, -2.39784993e-01, -2.66106257e-01,
#          6.88170145e-02, -3.49324324e-01, -2.47308786e-01, -1.58785307e-01,
#         -3.37904643e-01, -2.17121681e-01, -6.16350475e-01, -5.64243358e-01,
#         -3.29993040e-01, -2.49488018e-01, -2.17492411e-01, -2.25902585e-01,
#         -1.01458611e-01, -2.70185330e-01, -3.97170132e-01, -3.22666179e-01,
#         -3.65978652e-01, -2.62573358e-01, -2.14782046e-01, -3.21480015e-01,
#         -3.93249109e-01, -3.50948739e-01, -5.73185127e-01, -3.83270893e-01,
#         -2.25678155e-01, -3.49761237e-01, -2.71993289e-01, -2.32430614e-01,
#         -2.83218137e-01, -2.75924875e-01,  1.62419353e-01, -1.81602957e-01,
#         -1.98128851e-01, -2.32800389e-01, -4.35810508e-01, -3.12238062e-01,
#         -3.55245223e-01, -3.59077772e-01])}
